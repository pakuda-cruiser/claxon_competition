# %% [markdown]
# # INTRODUCTION
#
# This notebook looks into developing an end-to-end machine learning pipeline in Python to predict the probability of default (Credit risk modelling concept) using a financial dataset.
#
# We're going to take the following approach:
#
# - Problem definition
# - Data Cleaning and preprocessing
# - Feature Engineering
# - Feature selection
# - Modelling
# - Evaluation
# - Saving and deploying
#
# ### Problem Definition
#
# - Given socioeconomic details about a person, can we predict whether or not they are likely to default on a loan?
#
# ### Evaluation
#
# - If we can reach a considerable good roc-auc score in classification.

# %% [markdown]
# # Preparing the tools
#
# We're going to use pandas, Matplotlib and NumPy for data analysis and manipulation.

# %%
# Import all the tools we need

# Regular EDA (exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# we want our plots to appear inside the notebook
# %matplotlib inline 

# Models from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.cluster import KMeans
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA

# Model Evaluations
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, roc_curve

# %% [markdown]
# ### Load Data

# %%
 

df = pd.read_csv('data_science_competition_2024.csv')
df.columns
print(df.shape )# (rows, columns)
df.head(4)
# Out:
# (100000, 21)
#    Unnamed: 0                               loan_id  gender disbursemet_date  \
# 0           0  8d05de78-ff32-46b1-aeb5-b3190f9c158a  female       2022 10 29
# 1           1  368bf756-fcf2-4822-9612-f445d90b485b   other       2020 06 06
# 2           2  6e3be39e-49b5-45b5-aab6-c6556de53c6f   other       2023 09 29
# 3           3  191c62f8-2211-49fe-ba91-43556b307871  female       2022 06 22
#
#   currency   country     sex  is_employed      job    location  ...  \
# 0      USD  Zimbabwe  female         True  Teacher  Beitbridge  ...
# 1      USD  Zimbabwe   other         True  Teacher      Harare  ...
# 2      USD  Zimbabwe   other         True    Nurse       Gweru  ...
# 3      USD  Zimbabwe  female         True   Doctor      Rusape  ...
#
#    number_of_defaults  outstanding_balance  interest_rate  age  \
# 0                   0         48653.011473           0.22   37
# 1                   2         28752.062237           0.20   43
# 2                   1         44797.554126           0.22   43
# 3                   0         35681.496413           0.23   47
#
#    number_of_defaults.1  remaining term       salary  marital_status age.1  \
# 0                     0              47  3230.038869         married    37
# 1                     2              62  3194.139103          single    43
# 2                     1              57  3330.826656         married    43
# 3                     0              42  2246.797020        divorced    47
#
#        Loan Status
# 0  Did not default
# 1  Did not default
# 2  Did not default
# 3  Did not default
#
# [4 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# loan_id                    0
# gender                     0
# disbursemet_date           0
# currency                   0
# country                  100
# sex                        0
# is_employed                0
# job                     4136
# location                 595
# loan_amount                0
# number_of_defaults         0
# outstanding_balance        0
# interest_rate              0
# age                        0
# number_of_defaults.1       0
# remaining term             0
# salary                     0
# marital_status             0
# age.1                      0
# Loan Status                0
# dtype: int64

# %% [markdown]
# ### Class balance

# %%
df['Loan Status'].value_counts().plot(kind="bar", color=["salmon", "lightblue"]);

# %% [markdown]
# ## Structure overview
#
# - The dataset is has 100000 rows and 21 columns.
# - It has both categorical and numerical features.
# - It is extremely imbalanced
# - It has missing values in the `job`, `location` and `country` columns

# %% [markdown]
# # PRIMARY DATA CLEANING

# %% [markdown]
# ### Feature data type correction

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# loan_id                  object
# gender                   object
# disbursemet_date         object
# currency                 object
# country                  object
# sex                      object
# is_employed                bool
# job                      object
# location                 object
# loan_amount             float64
# number_of_defaults        int64
# outstanding_balance     float64
# interest_rate           float64
# age                       int64
# number_of_defaults.1      int64
# remaining term           object
# salary                  float64
# marital_status           object
# age.1                     int64
# Loan Status              object
# dtype: object

# %% [markdown]
# * remaining term data type looks suspicious since its labeled object yet it should be integer.

# %%
import pandas as pd


# Identify categorical columns
categorical_cols = ['job', 'location', 'marital_status', 'gender']

# Print value counts for each categorical column
for col in categorical_cols:
    print(f"Value counts for '{col}':")
    print(df[col].value_counts())
    print()
# Out:
# Value counts for 'job':
# job
# Engineer              16524
# Nurse                 15284
# Data Analyst          13204
# Doctor                12186
# Software Developer    11932
# Teacher                8950
# Accountant             7802
# SoftwareDeveloper      3564
# Data Scientist         3521
# Lawyer                 2862
# Data Scintist            35
# Name: count, dtype: int64
#
# Value counts for 'location':
# location
# Harare               8338
# Bulawayo             8078
# Mutare               8062
# Gweru                7803
# Masvingo             7476
#                      ...
#  Redcliff               1
# Victoria Falls          1
# Victoria Falls          1
#    Gokwe                1
# Gokwe                   1
# Name: count, Length: 157, dtype: int64
#
# Value counts for 'marital_status':
# marital_status
# married     44710
# divorced    26465
# single      25698
#              3127
# Name: count, dtype: int64
#
# Value counts for 'gender':
# gender
# male      35028
# female    32685
# other     32287
# Name: count, dtype: int64

# %% [markdown]
# ### From the above we can see that there is
# 1. Incorrect spellings further differentiating same categories in the `location`, `job` `currency` and `country`.
# 2. There is an additional unlabeled white space in the `marital_status` column.
# 3. `Remaining term` contains a mixture of both strings and integers.

# %% [markdown]
# ### Convert remaining term dtype

# %%
#Convert remaining term feature to consitenly become numeric

# Convert to string to handle non-numeric characters
df['remaining term'] = df['remaining term'].astype(str)

# Remove underscores and extra spaces
df['remaining term'] = df['remaining term'].str.replace('_', '').str.strip()

# Convert back to numeric if all values are intended to be numeric
df['remaining term'] = pd.to_numeric(df['remaining term'], errors='coerce')


df['remaining term'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# * converted the **remaining term** data type

# %% [markdown]
# ### Feature category spelling correction

# %%
print(df['location'].value_counts().sort_values().to_string())
#incorrect spellings for locations
# Out:
# location
# Gokwe                    1
#    Zvishavane            1
#  Victoria Falls          1
#    Gokwe                 1
# Victoria Falls           1
#  Redcliff                1
# Victoria Falls           1
#  Zvishavane              2
# Gokwe                    2
#  Victoria Falls          2
#  Gokwe                   2
#    Kariba                2
#    Kariba                3
#    Redcliff              3
#    Victoria Falls        3
#  Kariba                  3
#  Kariba                  3
# Kariba                   4
# Kariba                   4
#    Shurugwi              4
#    Zvishavane            4
# Kadoma                   5
#  Shurugwi                5
#    Nyanga                5
#  Nyanga                  5
#    Kadoma                6
# Zvishavane               6
#    Shurugwi              6
#  Gokwe                   6
#  Zvishavane              6
# Shurugwi                 6
# Zvishavane               6
#    Karoi                 6
#  Shurugwi                7
# Karoi                    7
#    Gokwe                 7
#  Karoi                   7
#  Nyanga                  8
# Nyanga                   8
#    Nyanga                8
#  Karoi                   9
# Nyanga                   9
# Shurugwi                 9
# Karoi                    9
#    Kwekwe               10
# Chiredzi                10
# Chipinge                10
#    Chimanimani          11
#    Karoi                11
# Chimanimani             11
#  Chiredzi               11
#    Chipinge             12
#    Kadoma               12
# Chiredzi                12
#  Kwekwe                 13
#  Chiredzi               14
# Beitbridge              14
#    Chiredzi             14
#  Kwekwe                 15
#    Chiredzi             15
# Chipinge                15
# Kadoma                  15
#  Kadoma                 15
# Chivhu                  15
#  Kadoma                 16
# Chimanimani             16
#  Chipinge               16
#    Plumtree             16
#  Chimanimani            16
#  Chipinge               16
#  Beitbridge             17
# Kwekwe                  17
# Kwekwe                  17
#  Rusape                 17
# Plumtree                18
#  Rusape                 18
#    Kwekwe               18
#  Chimanimani            18
#    Rusape               18
#    Plumtree             19
#    Chipinge             20
#    Chimanimani          20
# Plumtree                20
#  Beitbridge             21
#    Beitbridge           22
#  Gweru                  22
#  Masvingo               22
# Marondera               23
#  Plumtree               24
#  Plumtree               24
#    Rusape               24
# Beitbridge              24
# Masvingo                25
#    Chivhu               25
# Rusape                  25
# Rusape                  26
# Bulawayo                27
#    Chivhu               27
#    Marondera            27
#  Marondera              28
#  Bulawayo               28
#  Chivhu                 28
#  Chivhu                 29
# Gweru                   29
#    Marondera            30
# Chivhu                  30
#  Marondera              30
#    Bulawayo             30
#  Mutare                 30
# Mutare                  30
#    Gweru                30
# Masvingo                30
# Mutare                  31
#  Harare                 31
#  Harare                 31
#    Masvingo             32
#    Beitbridge           32
# Gweru                   32
#    Masvingo             32
# Marondera               32
# Bulawayo                33
#    Harare               33
#    Mutare               33
#  Gweru                  33
#    Bulawayo             33
#    Gweru                34
#  Bulawayo               34
# Harare                  36
#  Mutare                 37
#    Mutare               39
# Harare                  40
# Hwange                  41
#    Harare               44
#  Masvingo               48
# Redcliff               187
# Victoria Falls         211
# Kariba                 652
# Gokwe                  901
# Zvishavane            1276
# Shurugwi              1322
# Karoi                 1850
# Nyanga                2099
# Kadoma                3049
# Chiredzi              3123
# Kwekwe                3401
# Chimanimani           4296
# Chipinge              4358
# Beitbridge            5181
# Plumtree              5431
# Chivhu                6257
# Rusape                6378
# Marondera             7343
# Masvingo              7476
# Gweru                 7803
# Mutare                8062
# Bulawayo              8078
# Harare                8338

# %% [markdown]
# ### Correct and normalize location spellings

# %%
#location feature textual normalization
df['location'] = df['location'].str.strip()

# convert lowercase
df['location'] = df['location'].str.lower()

# Create a dictionary to map incorrect variations to correct values
mapping = {
    'harare': 'Harare',
    'bulawayo': 'Bulawayo',
    'mutare': 'Mutare',
    'gweru': 'Gweru',
    'masvingo': 'Masvingo',
    'marondera': 'Marondera',
    'rusape': 'Rusape',
    'chivhu': 'Chivhu',
    'plumtree': 'Plumtree',
    'beitbridge': 'Beitbridge',
    'chipinge': 'Chipinge',
    'chimanimani': 'Chimanimani',
    'kwekwe': 'Kwekwe',
    'chiredzi': 'Chiredzi',
    'kadoma': 'Kadoma',
    'nyanga': 'Nyanga',
    'karoi': 'Karoi',
    'shurugwi': 'Shurugwi',
    'zvishavane': 'Zvishavane',
    'gokwe': 'Gokwe',
    'kariba': 'Kariba',
    'victoria falls': 'Victoria Falls',
    'redcliff': 'Redcliff',
    'hwange': 'Hwange'
}

# Replace incorrect values using the mapping dictionary
df['location'] = df['location'].replace(mapping)



print(df['location'].value_counts())
# the locations are now normalized
# Out:
# location
# Harare            8553
# Bulawayo          8263
# Mutare            8262
# Gweru             7983
# Masvingo          7665
# Marondera         7513
# Rusape            6506
# Chivhu            6411
# Plumtree          5552
# Beitbridge        5311
# Chipinge          4447
# Chimanimani       4388
# Kwekwe            3491
# Chiredzi          3199
# Kadoma            3118
# Nyanga            2142
# Karoi             1899
# Shurugwi          1359
# Zvishavane        1301
# Gokwe              920
# Kariba             671
# Victoria Falls     219
# Redcliff           191
# Hwange              41
# Name: count, dtype: int64

# %% [markdown]
# ### Correct category spellings for currency, country and job.

# %%
print(df.currency.value_counts())
print()
print(df['country'].value_counts())
print()
print(df['job'].value_counts())
#Textual normalization required
# Out:
# currency
# USD     99980
# $USD       20
# Name: count, dtype: int64
#
# country
# Zimbabwe    99787
# zimbabwe      100
# Zim            13
# Name: count, dtype: int64
#
# job
# Engineer              16524
# Nurse                 15284
# Data Analyst          13204
# Doctor                12186
# Software Developer    11932
# Teacher                8950
# Accountant             7802
# SoftwareDeveloper      3564
# Data Scientist         3521
# Lawyer                 2862
# Data Scintist            35
# Name: count, dtype: int64

# %%
# function to correct spelling
def consistent_column_spelling(column, current_label, correctlabel):
    df.loc[df[column]== current_label, column] = correctlabel

# %%
#correcting feature categories

def consistent_column_spelling(column, current_label, correctlabel):
    df.loc[df[column]== current_label, column] = correctlabel
    return df.loc[:, column].value_counts()

consistent_column_spelling('currency', '$USD', 'USD')
consistent_column_spelling('job', 'Data Scintist', 'Data Scientist')
consistent_column_spelling('job', 'SoftwareDeveloper', 'Software Developer')
consistent_column_spelling('country', 'Zimbabwe', 'zimbabwe')
consistent_column_spelling('country', 'Zim', 'zimbabwe')

print(df.currency.value_counts())
print()
print(df['country'].value_counts())
print()
print(df['job'].value_counts())
# Out:
# currency
# USD    100000
# Name: count, dtype: int64
#
# country
# zimbabwe    99900
# Name: count, dtype: int64
#
# job
# Engineer              16524
# Software Developer    15496
# Nurse                 15284
# Data Analyst          13204
# Doctor                12186
# Teacher                8950
# Accountant             7802
# Data Scientist         3556
# Lawyer                 2862
# Name: count, dtype: int64

# %% [markdown]
# * Columns normalized

# %% [markdown]
# Drop unnecessary and redundant columns

# %%
# Drop unnecessary columns
df.drop(['loan_id', 'Unnamed: 0', 'age.1', 'number_of_defaults.1', 'sex'], axis=1, inplace=True)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
#
# #### The goal here is to find out more about the data and become a subject matter expert.
#
# 1. What question(s) are you trying to solve?
# 2. What kind of data do we have and how do we treat different types?
# 3. What's missing from the data and how do you deal with it?
# 4. Where are the outliers and why should you care about them?
# 5. How can you add, change or remove features to get more out of your data?

# %%
df.describe()
# Out:
#          loan_amount  number_of_defaults  outstanding_balance  interest_rate  \
# count  100000.000000       100000.000000        100000.000000  100000.000000
# mean    31120.000000            0.441970         36964.909763       0.210435
# std     15895.093631            0.688286         10014.758477       0.018725
# min      1000.000000            0.000000             0.000000       0.100000
# 25%     21000.000000            0.000000         29625.227472       0.200000
# 50%     31000.000000            0.000000         35063.852394       0.210000
# 75%     40000.000000            1.000000         42133.388817       0.220000
# max    273000.000000            2.000000        150960.000000       0.300000
#
#                 age  remaining term         salary
# count  100000.00000   100000.000000  100000.000000
# mean       43.57069       52.881870    2781.804324
# std         4.86376       11.985833     696.450055
# min        21.00000        0.000000     250.000000
# 25%        40.00000       45.000000    2273.929349
# 50%        44.00000       52.000000    2665.441567
# 75%        47.00000       61.000000    3146.577655
# max        65.00000      120.000000   10000.000000

# %%
print(df.shape)
print()
print(df.isna().sum())
# Out:
# (100000, 16)
#
# gender                    0
# disbursemet_date          0
# currency                  0
# country                 100
# is_employed               0
# job                    4136
# location                595
# loan_amount               0
# number_of_defaults        0
# outstanding_balance       0
# interest_rate             0
# age                       0
# remaining term            0
# salary                    0
# marital_status            0
# Loan Status               0
# dtype: int64

# %% [markdown]
# ### Univariate relationships
#
# - identify the distribution of the individual features

# %%
# univariate hist plots
fig, (ax,ax1) = plt.subplots(2,3,figsize=(20,8))
plt.suptitle('DISTRIBUTION PLOTS')
sns.histplot(df,x= 'age', bins=100,kde=True, ax=ax[0], color='darkcyan');
sns.histplot(df,x = 'interest_rate', bins=100,kde=True, ax=ax[1], color='salmon');
sns.histplot(df, x = 'salary', bins=100,kde=True, ax=ax[2], color='darkviolet');
sns.histplot(df, x = 'outstanding_balance', bins=100,kde=True, ax=ax1[0], color='yellow');
sns.histplot(df, x = 'remaining term', bins=100,kde=True, ax=ax1[1], color='gold');
sns.histplot(df, x = 'loan_amount', bins=100,kde=True, ax=ax1[2], color='darkgoldenrod');

fig, ax = plt.subplots(1,4,figsize=(20,5))
plt.suptitle('BOX PLOTS')
sns.boxplot(df, x='loan_amount', ax=ax[0]);
sns.boxplot(df, x='age', ax=ax[1]);
sns.boxplot(df, x='outstanding_balance', ax=ax[2]);
sns.boxplot(df, x='salary', ax=ax[3]);

# %% [markdown]
# #### Observations
#
# - age, interest rate are uniformly distributed.
# - outstanding balance, loan amount, salary and outstanding balance are skewed.
# - Loan amount has a sharp peak at the start.
# - outstanding balance and salary have considerable outliers.

# %% [markdown]
# #### Further investigate the sharp peak on loan amount distribution.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df[df['loan_amount']<100000]['loan_amount'], kde=True)
plt.title('Distribution of Loan Amounts below 10000')
plt.show()

# %% [markdown]
# - There is indeed a sharp peak at around $5000. Indicates a high number of points there.

# %% [markdown]
# ### Test if the numerical features are normally distributed using qqplots.

# %%
import statsmodels.graphics.gofplots as sm

plt.figure(figsize = (20,16));

fig, ((ax, ax1), (ax2,ax3), (ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize = (15,12));
       
sm.qqplot(df['interest_rate'], line='s', ax=ax);  # 's' for straight reference line
plt.xlabel('Theoretical Quantiles')
ax.set_ylabel('interest rates Quantiles')

sm.qqplot(df['salary'], line='s', ax=ax1);  # 's' for straight reference line
plt.xlabel('Theoretical Quantiles')
ax1.set_ylabel('salary Quantiles')

sm.qqplot(df['age'], line='s', ax=ax2);  # 's' for straight reference line
plt.xlabel('Theoretical Quantiles')
ax2.set_ylabel('age Quantiles')

sm.qqplot(df['loan_amount'], line='s', ax=ax3);  # 's' for straight reference line
plt.xlabel('Theoretical Quantiles')
ax3.set_ylabel('loan amount Quantiles')

sm.qqplot(df['remaining term'], line='s', ax=ax4);  # 's' for straight reference line
plt.xlabel('Theoretical Quantiles')
ax4.set_ylabel('remaining term Quantiles');
sm.qqplot(df['outstanding_balance'], line='s', ax=ax5);  # 's' for straight reference line
plt.xlabel('Theoretical Quantiles')
ax5.set_ylabel('outstanding balance Quantiles');

# %% [markdown]
# * **Loan amount** , **salary** and **outstanding balance** are highly deviating away from theoretical
# quantiles (red lines) and therefore they are not normally distributed.

# %% [markdown]
# ## Bivariate relationships

# %% [markdown]
# ### Countplots

# %%
fig, (ax, ax1, ax2) = plt.subplots(3,2,figsize=(15,18));

sns.countplot(df,x= 'gender', ax=ax[0], palette='magma', hue='Loan Status');
sns.countplot(df,x= 'marital_status', ax=ax[1], palette='spring', hue='Loan Status');
sns.countplot(df,x= 'number_of_defaults', ax=ax1[0], palette='rocket', hue='Loan Status');
sns.countplot(df,x= 'job', ax=ax1[1], palette='crest', hue='Loan Status');
sns.countplot(df,x= 'location', ax=ax2[0], palette='mako', hue='Loan Status', );
sns.countplot(df,x= 'is_employed', ax=ax2[1], palette='cividis', hue='Loan Status', );
ax2[0].set_xticks(ax2[0].get_xticks());
ax1[1].set_xticks(ax1[1].get_xticks());
ax2[0].set_xticklabels(ax2[0].get_xticklabels(), rotation=45, ha='right');
ax1[1].set_xticklabels(ax1[1].get_xticklabels(), rotation=45, ha='right');
plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# #### Observations
#
# - Towns like Chiredzi, Shurugwi, Gokwe, Karoi, Hwange and Kwekwe have high probability of defaulting.
# - Cities like Harare, Bulawayo, 'Mutare', 'Gweru have low probability of Default'.
# - People who are married are less likely to deafulted.
# - People with less previous defaults are less likely to deasex is roughly balanced.
# - There is an additional unlabeled marital status category.
# - Lawyers and Accountants have high probability of defaulting.

# %% [markdown]
# ## Lineplots

# %%
fig, (ax, ax1, ax2, ax3, ax4,ax5) = plt.subplots(6,2,figsize=(30,30))

plt.suptitle('BIVARIATE ANALYSIS (HUE=LOAN STATUS)', fontsize=20)
sns.lineplot(data=df, x='age', y='loan_amount', hue='Loan Status', lw=2, ax=ax[0]);
sns.lineplot(data=df, x='interest_rate', y='loan_amount', hue='Loan Status', lw=2, ax=ax[1]);
sns.lineplot(data=df, x='age', y='salary', hue='Loan Status', lw=2, ax=ax1[0]);
sns.lineplot(data=df, x='interest_rate', y='age', hue='Loan Status', lw=2, ax=ax1[1]);
sns.lineplot(data=df, x='interest_rate', y='remaining term', hue='Loan Status', lw=2, ax=ax2[0]);
sns.lineplot(data=df, x='age', y='remaining term', hue='Loan Status', lw=2, ax=ax2[1]);
sns.lineplot(data=df, x='age', y='loan_amount', hue='Loan Status', lw=2, ax=ax3[0]);
sns.lineplot(data=df, x='interest_rate', y='salary', hue='Loan Status', lw=2, ax=ax3[1]);
sns.lineplot(data=df, x='age', y='salary', hue='Loan Status', lw=2, ax=ax4[0]);
sns.lineplot(data=df, x='loan_amount', y='salary', hue='Loan Status', lw=2, ax=ax4[1]);
sns.lineplot(data=df, x='remaining term', y='salary', hue='Loan Status', lw=2, ax=ax5[0]);
sns.lineplot(data=df, x='remaining term', y='loan_amount', hue='Loan Status', lw=2, ax=ax5[1]);

# %% [markdown]
# #### Observations
#
# * The age vs loan_amount seems to be to seperate classes well in the first half.
# * The interest rate vs loan_amount seems to be to seperate classes well in the first 3 quarter.
# * Age is also a good seperator with salary.
# * Remaining term is also good in the last quarter.
# * Remaining term vs salary for deaulted and not defaulted increasing at the same rate.

# %% [markdown]
# ## Multivariate relationships

# %%
corrData = df.loc[:, [col for col in df if df[col].dtype not in ['category', 'object']]]
plt.figure(figsize=(10,6))
sns.heatmap(corrData.corr(), annot= True, linewidths=0.5,
                 fmt=".2f",
                 cmap="mako")
# Out:
# <Axes: >

# %% [markdown]
# ### There is considerable  is correlation between:-
#
# * **salary** and **loan amount**,
# * **salary** and **loan remaining term**,
# * **loan amount** and **outstanding_balance**

# %% [markdown]
# # SECONDARY DATA HANDLING
#
# ## HANDLING MISSING VALUES

# %%
df.isna().sum()
# Out:
# gender                    0
# disbursemet_date          0
# currency                  0
# country                 100
# is_employed               0
# job                    4136
# location                595
# loan_amount               0
# number_of_defaults        0
# outstanding_balance       0
# interest_rate             0
# age                       0
# remaining term            0
# salary                    0
# marital_status            0
# Loan Status               0
# dtype: int64

# %%
# fill job with median job
df.job.fillna('Data Analyst',inplace= True)
#fill with unknown for location
df.location.fillna('unknown',inplace= True)


df.isna().sum()
df1 = df.copy()
# Out:
# C:\Users\Augah\AppData\Local\Temp\ipykernel_5980\3365732677.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.job.fillna('Data Analyst',inplace= True)
# C:\Users\Augah\AppData\Local\Temp\ipykernel_5980\3365732677.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.location.fillna('unknown',inplace= True)

# %% [markdown]
# ## Earlier
#
# - Earlier we discovered that the marital status feature has a category called " " white space.
# - We want to predict this category into its corresponding valid category using the XGB MODEL.
# - We are going to use the custom made predict feature class.

# %% [markdown]
# ## Data preprocessing

# %%
#Create a column to seperate Indutrial, Towns and the rest

df['Category'] = df['location'].apply(lambda x: 
                                     
                                     2 if x in [
    
    'Karoi',
    'Hwange',
     'Chiredzi',
    'Gokwe',
    'Shurugwi',
    'Victoria Falls',
    
    ] else 0 if x in ['Nyanga', 'Chivhu', 'Kadoma', 'Marondera', 'Gweru', 'Masvingo', 'Harare', 'Bulawayo', 'Mutare'] else 1 )

# copy df for training the pipeline

# %% [markdown]
# ### Encoding columns

# %%
# encode categorical variables

from sklearn.preprocessing import LabelEncoder

df['gender'] = df['gender'].map({"other":1, "female": 0,'male':2}).astype('int')

label_encodings = {}
label_models = {}

# Initialize the LabelEncoder
le = LabelEncoder()

# List of categorical features
categorical_features = ['currency', 'country', 'job', 'location']

# Encode each categorical feature and store the mappings
for cat in categorical_features:
    label_models[cat] = le.fit(df[cat])
    label_encodings[cat] = dict(zip(le.classes_, le.transform(le.classes_)))
    df[cat] = le.fit_transform(df[cat])
    
le.fit([ 'Defaulted','Did not default'])
if df['Loan Status'].dtype != 'int64':
    df['Loan Status'] = df['Loan Status'].map({'Did not default': 0, 'Defaulted': 1}).astype('int')
label_models

# df['marital_status'] = df['marital_status'].map({'single': 0, 'married': 1, 'divorced': 2, ' ':3}).astype('int')
# Out:
# {'currency': LabelEncoder(),
#  'country': LabelEncoder(),
#  'job': LabelEncoder(),
#  'location': LabelEncoder()}

# %% [markdown]
# ## EARLIER
#
# - Earlier we discovered that the marital status feature has a category called " " white space.
# - We want to predict this category into its corresponding valid category using an XGB MODEL.
# - We are going to use the custom made predict feature class.

# %%
import importlib
import predict_feature
importlib.reload(predict_feature)
from predict_feature import Predict_Marital
import xgboost as xgb





mdl = Predict_Marital(df.drop('disbursemet_date', axis =1))
mdl.train()

preds, feature_importances = mdl.predict()

df.loc[df.marital_status  == ' ', 'marital_status']

df.loc[df.marital_status  == ' ', 'marital_status'] =pd.DataFrame(preds)[0].map({0:'single', 1:'married', 2:'divorced'}).to_numpy()
df['marital_status'] = df['marital_status'].map({'single':0, 'married':1, 'divorced': 2}).astype('int')

print(df.marital_status.value_counts())

X = df.drop(columns=['Loan Status', 'disbursemet_date'])
y = df['Loan Status']
# Out:
# score: 0.9016258064516129
# marital_status
# 1    46196
# 2    27291
# 0    26513
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Engineering
#
# #### Create new features

# %%
## function to encode a categorical feature ordinaly with respect to another feature with mean
def group_sort_map(X, groupby_column, sort_by_column):
    """
    Group X by a given column, calculate the mean, sort by another column,
    and map the groupby column to its corresponding index after sorting.

    Parameters:
    - X (pd.DataFrame): The input DataFrame to process.
    - groupby_column (str): The column name to group by.
    - sort_by_column (str): The column name to sort by.

    Returns:
    - sorted_groupby_df (pd.DataFrame): The grouped and sorted DataFrame.
    - location_to_index (dict): A mapping of groupby column values to their sorted indices.
    """
    
    # 1. Group by the specified column and calculate the mean
    groupby_df = X.groupby(groupby_column).mean()
    
    # 2. Sort the resulting DataFrame by the specified column
    sorted_groupby_df = groupby_df.sort_values(by=sort_by_column)
    
    # 3. Map the groupby column to its corresponding index after sorting
    feature_to_index = {feature: index for index, feature in enumerate(sorted_groupby_df.index)}
    index_to_feature = {index: feature for index, feature in enumerate(sorted_groupby_df.index)}
    
    
    return  feature_to_index, index_to_feature

# ordinally encode location by loan_amount mean per location
location_map, ind_to_feature_location=group_sort_map(X= X, groupby_column='location', sort_by_column='loan_amount' )
X['location'] = X['location'].map(location_map).astype('int')

# ordinally encode location by loan_amount mean per location
job_map, ind_to_feature_job=group_sort_map(X= X, groupby_column='job', sort_by_column='salary' )
X['job'] = X['job'].map(job_map).astype('int')

# %%
# independent binary features for loan_amount === 5000 and greater than 75000
X['loan_equal_5000'] = np.where(X.loan_amount==5000,1,0)
X['loan_>_75000'] = np.where(X.loan_amount>75000,1,0)

# %%
# create a feature for loan amount per job
X = X.assign(total_loan_amount_per_job=X.groupby('job')['loan_amount'].transform('mean'))

### Create new feature to capture job and location relationship
X['job_location_interact'] = np.log1p(np.sqrt(X['job']))/(X['location']+1)

# %% [markdown]
# **Add the location threshold classification in train data only to avoid data leakage since we are using the target varible**

# %%
# Create a feature for threshold classification of locations
def location_thresh_classification(X_features, labels, apply_data, threshold= 0.2):
    X_features = X_features.copy()
    X_features['y'] = labels
    location_ratios = X_features.groupby('location')['y'].mean()
    location_ratios = location_ratios / (1 - location_ratios)
  
    ## Define a threshold for classification (example: 0.2)
    threshold = 0.2
    #drop the labels if features equal to the apply
    if apply_data.shape == X_features.shape:
        X_features.drop('y',axis = 1, inplace = True)
    ## Classify locations based on imbalance ratio

    X_features.drop (columns ='y', axis = 1, inplace = True)
    apply_data['location_class'] = apply_data['location'].map(lambda loc: 1 if location_ratios[loc] < threshold else 0)
    return apply_data

# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# ### Checking for association between categorical variables using chi square and p_values.

# %%
import pandas as pd
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

# Assume X and y are already defined and preprocessed dataframes
# Initialize the output dictionary
out = {'chi': [], 'p_value': [], 'col': []}

# Iterate over the categorical columns
for i in (X.columns[~X.columns.isin(['loan_amount', 'outstanding_balance', 'salary', 'total_loan_amount_per_job', 'age', 'interest_rate', 'remaining_term'])]):
    # Create a contingency table
    observed_data = pd.crosstab(X[i], y).to_numpy()

    # Perform the Chi-Square test
    chi2_statistic, pval, dof, expected_frequency = chi2_contingency(observed_data)

    # Store the results
    out['chi'].append(chi2_statistic)
    out['p_value'].append(pval)
    out['col'].append(i)

# Create a DataFrame for chi-square values and p-values
chi_X = pd.DataFrame(out)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(chi_X['col'], chi_X['chi'], marker='o', color='salmon', label='Chi-Square')

# Adding p-values as text on the plot
for i, (col, chi, pval) in enumerate(zip(chi_X['col'], chi_X['chi'], chi_X['p_value'])):
    ax.text(i, chi, f'p={pval:.3f}', ha='center', va='bottom', color='green', fontsize=10)

# Adding labels and title
ax.set_xlabel('Categorical Column')
ax.set_ylabel('Chi-Square')
ax.set_title('Chi-Square Values for Categorical Columns')
ax.legend()

plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Currency** and **country** have p_values of greater than 0.05 indicating no significance with target variable.
# - **Location**, **category** and **job_location_interaction** have very high chi coefficients indicating very strong significance.

# %% [markdown]
# #### Using variance thresholds to select features

# %%
from sklearn.feature_selection import  VarianceThreshold
from sklearn.linear_model import LassoCV

selector = VarianceThreshold(threshold=0.01)
X_high_variance = selector.fit_transform(X)
X.columns[~X.columns.isin(selector.get_feature_names_out())]
# Out:
# Index(['currency', 'country', 'interest_rate', 'loan_>_75000'], dtype='object')

# %%
from sklearn.feature_selection import RFE


model = RandomForestClassifier(n_estimators=100)
rfe = RFE(model, n_features_to_select=12)
fit = rfe.fit(X, y)
selected_features_rfe = X.columns[~fit.support_]
selected_features_rfe
# Out:
# Index(['currency', 'country', 'is_employed', 'number_of_defaults',
#        'loan_equal_5000', 'loan_>_75000'],
#       dtype='object')

# %% [markdown]
# - `currency` and `country` are in every selection method and should be removed.

# %%
X.drop(columns=[ 'country', 'currency'], inplace= True)

# %% [markdown]
# # PREDICTIVE MODELLING
#
# ## MODEL SELECTION
#
# We are going to try the following algorithms.
#
# 1. Catboost
# 2. XGBOOST
# 3. RandomForestClassier
# 4. KNearest Neighbours
# 5. Logistic Regression
# 6. Decision Tress
# 7. LightGBM
#
# * We are then going to select our model based on the cross validation score using roc auc score.
# * We are going to use five folds.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold, train_test_split
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from lightgbm import LGBMClassifier
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import warnings
warnings.filterwarnings('ignore')


# Set the aesthetic style of the plots
sns.set_theme(style="whitegrid")
palette = sns.color_palette("Set2")

stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fitted_models = []

models = {
    'Logistic Regression': LogisticRegression(verbose=0),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Xgboost': XGBClassifier(),
    'Catboost': CatBoostClassifier(verbose=0),
    'Knn': KNeighborsClassifier(),
    'lightGBM': LGBMClassifier(verbose = 0),
    'Quadratic Discriminant Analysis': QuadraticDiscriminantAnalysis()
}

def cross_val(X, y, show_plots=True, models = models):
    


    scoring = {
        'roc_auc': 'roc_auc',
        'recall': 'recall',
        'precision': 'precision',
        'accuracy': 'accuracy'
    }

    mean_scores = {metric: {} for metric in scoring}
    cv_results = {metric: {} for metric in scoring}

    for name, model in models.items():
        for metric in scoring:
            cv_scores = cross_val_score(model, X, y, cv=stratified_kfold, scoring=scoring[metric])
            cv_results[metric][name] = cv_scores
            mean_scores[metric][name] = cv_scores.mean()
        fitted_models.append(model)

    cv_dfs = {metric: pd.DataFrame(results) for metric, results in cv_results.items()}

    if show_plots:
        fig, axs = plt.subplots(3, 2, figsize=(20, 20))
        fig.suptitle('Cross-Validation Scores for Different Models', fontsize=20, weight='bold')

        metrics = list(cv_dfs.keys())
        for i, metric in enumerate(metrics):
            ax = axs[i // 2, i % 2]
            sns.boxplot(data=cv_dfs[metric], ax=ax, palette=palette)
            ax.set_title(f'{metric.upper()} Scores', fontsize=14, weight='bold')
            ax.set_xlabel('Model', fontsize=12)
            ax.set_ylabel(f'{metric.upper()} Score', fontsize=12)
            ax.tick_params(axis='x', rotation=45)
            ax.grid(True)

        # Hide any unused subplots
        for j in range(len(metrics), 6):
            fig.delaxes(axs[j // 2, j % 2])

        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()

    return mean_scores, cv_results

# %% [markdown]
# ### Split and cross validate our data

# %% [markdown]
# * We are splitting our data so that we can have a seperate testing set later which is unaltered.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=87)

# %%
X_train = location_thresh_classification(X_train, y_train, X_train)
mean_scores, cv_results = cross_val(X_train, y_train)
mean_scores
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# {'roc_auc': {'Logistic Regression': 0.7790640399249997,
#   'Decision Tree': 0.7652353418585878,
#   'Random Forest': 0.8930524334966539,
#   'Xgboost': 0.9009144715703,
#   'Catboost': 0.9074733169680279,
#   'Knn': 0.620794783311615,
#   'lightGBM': 0.9030109954428642,
#   'Quadratic Discriminant Analysis': 0.8496155283589315},
#  'recall': {'Logistic Regression': 0.1582417430905622,
#   'Decision Tree': 0.6043061113308876,
#   'Random Forest': 0.6026239548389308,
#   'Xgboost': 0.6361729401961586,
#   'Catboost': 0.6351643604273587,
#   'Knn': 0.17758343170247373,
#   'lightGBM': 0.6105281671593079,
#   'Quadratic Discriminant Analysis': 0.5187076009560809},
#  'precision': {'Logistic Regression': 0.7140604698749798,
#   'Decision Tree': 0.5805088750122055,
#   'Random Forest': 0.8873708533859321,
#   'Xgboost': 0.8744719788771279,
#   'Catboost': 0.8918750108002669,
#   'Knn': 0.4844234661136637,
#   'lightGBM': 0.8843384199089048,
#   'Quadratic Discriminant Analysis': 0.5817827780773484},
#  'accuracy': {'Logistic Regression': 0.8655125,
#   'Decision Tree': 0.8759375,
#   'Random Forest': 0.92995,
#   'Xgboost': 0.9323375,
#   'Catboost': 0.9343,
#   'Knn': 0.8496,
#   'lightGBM': 0.9302249999999999,
#   'Quadratic Discriminant Analysis': 0.8730249999999999}}

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score,StratifiedKFold
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from lightgbm import LGBMClassifier

stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fitted_models = []

def cross_val(X, y, show_plots= True):
    
    models = {
        'Logistic Regression': LogisticRegression(max_iter=100000),
        'Decision Tree': DecisionTreeClassifier(),
        'Random Forest': RandomForestClassifier(),
        'Xgboost': XGBClassifier(),
        'Catboost': CatBoostClassifier(verbose= 0),
        'Knn': KNeighborsClassifier(),
        'lightGBM': LGBMClassifier()
    }
    mean_scores = {}
    cv_results = {}

    for name, model in models.items():
        cv_scores = cross_val_score(model, X, y, cv=stratified_kfold, scoring='roc_auc');
        cv_results[name] = cv_scores
        mean_scores[name] = cv_scores.mean()
        fitted_models.append(model)

    cv_df = pd.DataFrame(cv_results)

    if show_plots == True:
        # Plotting
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=cv_df)
        plt.title('Cross-Validation ROC-AUC Scores for Different Models')
        plt.xlabel('Model')
        plt.ylabel('ROC-AUC Score')
        plt.show()
        print(mean_scores )  


    return mean_scores, cv_results

# %% [markdown]
# ## Chosen Algorithm: CatBoost
#
# ### Reason for Choice
#
# After evaluating all the models, we selected **CatBoost** for the following reasons:
#
# - **Performance**: CatBoost consistently demonstrated superior performance across multiple metrics, including accuracy, precision, recall, and ROC AUC score.
# - **Handling Categorical Data**: CatBoost natively handles categorical variables, which simplifies preprocessing and improves model accuracy.
# - **Overfitting Prevention**: It includes built-in mechanisms to reduce overfitting, which is particularly useful for our dataset.
#
# ### Assumptions and Limitations
#
# #### Assumptions
#
# - **Categorical Variables**: Assumes that categorical variables are significant predictors and can be encoded in a way that preserves their information.
# - **Boosting**: Assumes that boosting weak learners sequentially can improve the model's overall performance.
#
# #### Limitations
#
# - **Computational Complexity**: Training CatBoost can be computationally intensive, especially with large datasets like this one.
# - **Parameter Tuning**: The model requires careful tuning of hyperparameters to achieve optimal performance, which can be time-consuming.
# - **Data Size**: While it handles categorical data well, very large datasets may require significant computational resources.
#
# By thoroughly evaluating multiple algorithms and considering their assumptions and limitations, its ensured that CatBoost provides the best balance of accuracy, efficiency, and robustness for our specific predictive modeling task.

# %% [markdown]
# ### Assess and verify the score on each fold.

# %%
from numpy import interp
from sklearn.metrics import auc


def plot_roc(X, y, estimator,n_splits, lns = 100):
    #creating an instance of KFold
    kfold = StratifiedKFold(n_splits=n_splits,shuffle=False)
    #define estemator
    rf = estimator
    #deifne figuresize
    plt.rcParams['figure.figsize'] = (10,5)
    
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0,1,lns)
    i = 1

    for train,test in kfold.split(X,y):
        #get prediction
        prediction = rf.fit(X.iloc[train],y.iloc[train]).predict_proba(X.iloc[test])
        #get the true pos. rate, false positive rate and thresh 
        fpr, tpr, t = roc_curve(y.iloc[test], prediction[:, 1])
        tprs.append(interp(mean_fpr, fpr, tpr))
        #get the area under the curve
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        #plot the tpr and fpr
        plt.plot(fpr, tpr, lw=2, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))
        i= i+1

    #plot the mean ROC
    plt.plot([0,1],[0,1],linestyle = '--',lw = 2,color = 'black')
    mean_tpr = np.mean(tprs, axis=0)
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, color='gold',
    label=r'Mean ROC (AUC = %0.2f )' % (mean_auc),lw=2, alpha=1)

    #setup the labels
    plt.legend(bbox_to_anchor=(1, 1))
    plt.title('ROC PLOT', fontsize=16)
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)

# %%
plot_roc(X_train, y_train, XGBClassifier(), 5)

# %% [markdown]
# * The scores on individual folds are extremely close.

# %% [markdown]
# ## **Earlier**
#
# We identified that
#
# 1. There is a secondary distribution on loan amount from 1000 to 10000.
# 2. There are outliers on loan amount greater than 75000
#
# We therefore want to train the model on that secondary distribution and the outliers and try to create ensemble models of the three models.

# %%
# scores for less than 10000
X_train_0_to_10000 = X_train[X_train['loan_amount']<=10000]
y_train_0_to_10000 = y_train[X_train['loan_amount']<=10000]

cross_val(X_train_0_to_10000, y_train_0_to_10000)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# ({'roc_auc': {'Logistic Regression': 0.8765014549903263,
#    'Decision Tree': 0.852982282433884,
#    'Random Forest': 0.9571742977279655,
#    'Xgboost': 0.9542873276464539,
#    'Catboost': 0.9606931798687801,
#    'Knn': 0.7312090065533947,
#    'lightGBM': 0.9578660485437014,
#    'Quadratic Discriminant Analysis': 0.6637099625828163},
#   'recall': {'Logistic Regression': 0.7631377329962769,
#    'Decision Tree': 0.8260800449408657,
#    'Random Forest': 0.8627319504455242,
#    'Xgboost': 0.8654995189175946,
#    'Catboost': 0.8710280820648894,
#    'Knn': 0.5698406153073847,
#    'lightGBM': 0.8703408214855586,
#    'Quadratic Discriminant Analysis': 0.8127256754576259},
#   'precision': {'Logistic Regression': 0.7701194544078827,
#    'Decision Tree': 0.8250989368177134,
#    'Random Forest': 0.9290490478334531,
#    'Xgboost': 0.9158077455966765,
#    'Catboost': 0.9273628126174172,
#    'Knn': 0.6499941267143245,
#    'lightGBM': 0.9215377144282225,
#    'Quadratic Discriminant Analysis': 0.48918135269186014},
#   'accuracy': {'Logistic Regression': 0.8091725675850053,
#    'Decision Tree': 0.855885057100458,
#    'Random Forest': 0.9173656364926769,
#    'Xgboost': 0.9119700262920188,
#    'Catboost': 0.918926926737209,
#    'Knn': 0.6972890388089554,
#    'lightGBM': 0.9162301801729145,
#    'Quadratic Discriminant Analysis': 0.5427746346538486}},
#  {'roc_auc': {'Logistic Regression': array([0.87742496, 0.86411969, 0.88143247, 0.86913328, 0.89039688]),
#    'Decision Tree': array([0.85204802, 0.84900535, 0.85812161, 0.85561763, 0.85011881]),
#    'Random Forest': array([0.95759892, 0.94983145, 0.95320453, 0.95631071, 0.96892588]),
#    'Xgboost': array([0.95272715, 0.9499615 , 0.95402751, 0.95143619, 0.96328428]),
#    'Catboost': array([0.96039291, 0.9542897 , 0.95915892, 0.95822946, 0.97139492]),
#    'Knn': array([0.71888207, 0.72324427, 0.75258963, 0.73153166, 0.72979739]),
#    'lightGBM': array([0.95942688, 0.95124332, 0.9549743 , 0.95543628, 0.96824947]),
#    'Quadratic Discriminant Analysis': array([0.71454328, 0.6487983 , 0.69446283, 0.60704965, 0.65369575])},
#   'recall': {'Logistic Regression': array([0.75778547, 0.76683938, 0.76511226, 0.74740484, 0.77854671]),
#    'Decision Tree': array([0.83044983, 0.82037997, 0.80829016, 0.83044983, 0.84083045]),
#    'Random Forest': array([0.85813149, 0.8566494 , 0.84801382, 0.8615917 , 0.88927336]),
#    'Xgboost': array([0.8633218 , 0.85319516, 0.85319516, 0.8650519 , 0.89273356]),
#    'Catboost': array([0.86678201, 0.86183074, 0.86701209, 0.8650519 , 0.89446367]),
#    'Knn': array([0.56055363, 0.56994819, 0.59067358, 0.57093426, 0.55709343]),
#    'lightGBM': array([0.86678201, 0.85837651, 0.8566494 , 0.87197232, 0.89792388]),
#    'Quadratic Discriminant Analysis': array([0.87197232, 0.61139896, 0.61139896, 0.97750865, 0.99134948])},
#   'precision': {'Logistic Regression': array([0.77659574, 0.75767918, 0.771777  , 0.76868327, 0.77586207]),
#    'Decision Tree': array([0.83448276, 0.83101045, 0.84172662, 0.82222222, 0.79605263]),
#    'Random Forest': array([0.92236599, 0.94252874, 0.93499044, 0.91896869, 0.92639138]),
#    'Xgboost': array([0.90727273, 0.93207547, 0.91992551, 0.92081031, 0.8989547 ]),
#    'Catboost': array([0.91758242, 0.94507576, 0.92962963, 0.9310987 , 0.91342756]),
#    'Knn': array([0.64031621, 0.62977099, 0.66407767, 0.6639839 , 0.65182186]),
#    'lightGBM': array([0.91090909, 0.93773585, 0.92022263, 0.9298893 , 0.9089317 ]),
#    'Quadratic Discriminant Analysis': array([0.5060241 , 0.49859155, 0.61139896, 0.41913947, 0.41075269])},
#   'accuracy': {'Logistic Regression': array([0.81121363, 0.80340667, 0.8105039 , 0.80397727, 0.81676136]),
#    'Decision Tree': array([0.85734564, 0.85592619, 0.85592619, 0.85866477, 0.8515625 ]),
#    'Random Forest': array([0.91838183, 0.91625266, 0.9112846 , 0.91335227, 0.92755682]),
#    'Xgboost': array([0.90773598, 0.91412349, 0.90915543, 0.9140625 , 0.91477273]),
#    'Catboost': array([0.91341377, 0.92264017, 0.91838183, 0.91832386, 0.921875  ]),
#    'Knn': array([0.69056068, 0.68559262, 0.70901348, 0.70525568, 0.69602273]),
#    'lightGBM': array([0.91057488, 0.91838183, 0.91057488, 0.92045455, 0.92116477]),
#    'Quadratic Discriminant Analysis': array([0.59829666, 0.58765082, 0.68062456, 0.43465909, 0.41264205])}})

# %% [markdown]
# - There is a higher score of 0.97 with catboost having highest score

# %%
X_train_outlier = X_train[X_train['loan_amount']>75000]
y_train_outlier = y_train[X_train['loan_amount']>75000]

cross_val(X_train_outlier, y_train_outlier)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ({'roc_auc': {'Logistic Regression': 0.9291153846153846,
#    'Decision Tree': 0.8298717948717949,
#    'Random Forest': 0.9593717948717948,
#    'Xgboost': 0.9523974358974359,
#    'Catboost': 0.9674102564102564,
#    'Knn': 0.7447371794871794,
#    'lightGBM': 0.9434102564102563,
#    'Quadratic Discriminant Analysis': nan},
#   'recall': {'Logistic Regression': 0.76,
#    'Decision Tree': 0.72,
#    'Random Forest': 0.8,
#    'Xgboost': 0.82,
#    'Catboost': 0.76,
#    'Knn': 0.13999999999999999,
#    'lightGBM': 0.72,
#    'Quadratic Discriminant Analysis': 0.76},
#   'precision': {'Logistic Regression': 0.8777777777777779,
#    'Decision Tree': 0.7548268398268398,
#    'Random Forest': 0.8564141414141414,
#    'Xgboost': 0.864090909090909,
#    'Catboost': 0.881984126984127,
#    'Knn': 0.5999999999999999,
#    'lightGBM': 0.8346608946608945,
#    'Quadratic Discriminant Analysis': 0.22617753623188402},
#   'accuracy': {'Logistic Regression': 0.9317551020408164,
#    'Decision Tree': 0.8876734693877552,
#    'Random Forest': 0.9318367346938775,
#    'Xgboost': 0.9358367346938774,
#    'Catboost': 0.9319183673469388,
#    'Knn': 0.7952653061224491,
#    'lightGBM': 0.9117551020408163,
#    'Quadratic Discriminant Analysis': 0.5288979591836734}},
#  {'roc_auc': {'Logistic Regression': array([0.8825    , 0.8775    , 1.        , 0.9625    , 0.92307692]),
#    'Decision Tree': array([0.775     , 0.825     , 0.825     , 0.85      , 0.87435897]),
#    'Random Forest': array([0.9025    , 0.9675    , 0.99      , 0.9625    , 0.97435897]),
#    'Xgboost': array([0.9475    , 0.865     , 0.99      , 0.98      , 0.97948718]),
#    'Catboost': array([0.93      , 0.97      , 0.985     , 0.97      , 0.98205128]),
#    'Knn': array([0.69875  , 0.86625  , 0.75875  , 0.6025   , 0.7974359]),
#    'lightGBM': array([0.91      , 0.89      , 0.9825    , 0.9525    , 0.98205128]),
#    'Quadratic Discriminant Analysis': array([       nan, 0.755     , 0.8575    , 0.8575    , 0.88974359])},
#   'recall': {'Logistic Regression': array([0.5, 0.7, 1. , 0.8, 0.8]),
#    'Decision Tree': array([0.6, 0.8, 0.6, 0.7, 0.9]),
#    'Random Forest': array([0.9, 0.7, 0.9, 0.7, 0.8]),
#    'Xgboost': array([0.9, 0.8, 0.9, 0.7, 0.8]),
#    'Catboost': array([0.9, 0.7, 0.7, 0.6, 0.9]),
#    'Knn': array([0.1, 0.2, 0.1, 0.1, 0.2]),
#    'lightGBM': array([0.8, 0.7, 0.8, 0.6, 0.7]),
#    'Quadratic Discriminant Analysis': array([0. , 0.9, 1. , 0.9, 1. ])},
#   'precision': {'Logistic Regression': array([0.83333333, 0.77777778, 1.        , 0.88888889, 0.88888889]),
#    'Decision Tree': array([0.7       , 0.66666667, 0.71428571, 0.875     , 0.81818182]),
#    'Random Forest': array([0.81818182, 0.7       , 0.88888889, 0.875     , 1.        ]),
#    'Xgboost': array([0.9       , 0.72727273, 0.81818182, 0.875     , 1.        ]),
#    'Catboost': array([0.9       , 0.77777778, 0.875     , 0.85714286, 1.        ]),
#    'Knn': array([0.5       , 0.66666667, 1.        , 0.16666667, 0.66666667]),
#    'lightGBM': array([0.88888889, 0.7       , 0.72727273, 0.85714286, 1.        ]),
#    'Quadratic Discriminant Analysis': array([0.        , 0.28125   , 0.25      , 0.39130435, 0.20833333])},
#   'accuracy': {'Logistic Regression': array([0.88      , 0.9       , 1.        , 0.94      , 0.93877551]),
#    'Decision Tree': array([0.88      , 0.84      , 0.86      , 0.94      , 0.91836735]),
#    'Random Forest': array([0.92      , 0.88      , 0.98      , 0.92      , 0.95918367]),
#    'Xgboost': array([0.96      , 0.9       , 0.94      , 0.92      , 0.95918367]),
#    'Catboost': array([0.96      , 0.9       , 0.92      , 0.9       , 0.97959184]),
#    'Knn': array([0.8       , 0.82      , 0.82      , 0.72      , 0.81632653]),
#    'lightGBM': array([0.94      , 0.88      , 0.9       , 0.9       , 0.93877551]),
#    'Quadratic Discriminant Analysis': array([0.8      , 0.52     , 0.4      , 0.7      , 0.2244898])}})

# %% [markdown]
# - There is a higher score of 0.97 with catboost having highest score

# %% [markdown]
# # MODEL EVALUATION

# %% [markdown]
# ### Baseline model

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# function to evaluate our model
def train_evaluate_model(X_train, y_train, X_test, y_test,model = CatBoostClassifier(learning_rate=0.070, verbose=0), threshold = 0.5,show_plots = False):
    # Initialize and train the CatBoost model
    model.fit(X_train, y_train);
    
    # Apply any additional preprocessing to the test set if needed
    X_test_processed = location_thresh_classification(X_train, y_train, X_test)
    
    # Predict on the test set
    
    y_pred_proba = model.predict_proba(X_test_processed)[:, 1]
    y_pred_proba = np.where(X_test['number_of_defaults'] <1, y_pred_proba-0.015, y_pred_proba)
    y_pred_proba = np.where(X_test['interest_rate'] <=13, y_pred_proba+0.1, y_pred_proba)
    y_pred_proba = np.where(X_test['number_of_defaults'] >=2, y_pred_proba+0.025, y_pred_proba)
    y_pred = np.where(y_pred_proba>=threshold, 1,0).astype('int')
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred_proba)
    report = classification_report(y_test, y_pred)
    if show_plots == True:
        auc = roc_auc_score(y_test, y_pred_proba)
        # Calculate ROC curve (fpr, tpr, thresholds)
        fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
        # fpr, tpr, thresholds = roc_curve(y_test, y_preds)
        J = tpr - fpr
        ix = np.argmax(J)
        optimal_threshold = thresholds[ix]
        print(f"Optimal Threshold (ROC): {optimal_threshold}")
        
        # Plot ROC curve
        print(auc)
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, label='ROC Curve (area = %0.4f)' % auc)
        plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random chance
        plt.title('ROC Curve')
        plt.xlabel('False Positive Rate (FPR)')
        plt.ylabel('True Positive Rate (TPR)')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.0])
        plt.legend(loc='lower right')
        plt.grid()
        plt.show()
        
        

    return {
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1,
    'ROC AUC': roc_auc
    }, model,report, y_pred, y_pred_proba

# %%
base_model_metrics, model,report, y_pred, y_pred_proba= train_evaluate_model(X_train, y_train, X_test, y_test)
for metric, value in base_model_metrics.items():
    print(f"{metric}: {value}")
# Out:
# Accuracy: 0.93765
# Precision: 0.8742411101474414
# Recall: 0.6781029263370333
# F1 Score: 0.7637810191324115
# ROC AUC: 0.9208676526513923

# %% [markdown]
# ### **We are going to try an ensemble model using :-**
#
# 1. points with loan amount less than 10000
# 2. points with loan amount greater than 75000 (outliers)
# 3. base model for the rest of the points

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# function to classify for different loan_amount conditions
def train_and_evaluate_models(X_train, y_train, X_test, y_test):

    # X_test = location_thresh_classification(X_train, y_train, X_test)
    X_test = X_test
    models = {
        'loan under 10000': CatBoostClassifier(verbose=0),
        'loan above 75000': CatBoostClassifier(verbose=0),
        'base_model for loan inbetween': CatBoostClassifier(verbose=0)
    }
    
    # Define conditions for training subsets
    conditions = {
        'loan under 10000': X_train['loan_amount'] < 10000,
        'loan above 75000': X_train['loan_amount'] > 75000,
        'base_model for loan inbetween': (X_train['loan_amount'] > 0) & (X_train['loan_amount'] < 1000000)
    }
    
    # Train models
    for model_name, condition in conditions.items():
        X_train_subset = X_train[condition]
        y_train_subset = y_train[condition]
        models[model_name].fit(X_train_subset, y_train_subset)

    # Define test conditions
    test_conditions = {
        'loan under 10000': X_test['loan_amount'] < 10000,
        'loan above 75000': X_test['loan_amount'] > 75000,
        'base_model for loan inbetween': (X_test['loan_amount'] >= 10000) & (X_test['loan_amount'] <= 75000)
    }
    
    # Evaluate models
    def evaluate_model(model, X, y):
        y_pred_proba = model.predict_proba(X)[:, 1]
        y_pred = model.predict(X)
        return {
            "ROC AUC": roc_auc_score(y, y_pred_proba),
            "Accuracy": accuracy_score(y, y_pred),
            "Precision": precision_score(y, y_pred),
            "Recall": recall_score(y, y_pred),
            "F1 Score": f1_score(y, y_pred),
        }

    metrics = {}
    for model_name, condition in test_conditions.items():
        X_test_subset = X_test[condition]
        y_test_subset = y_test[condition]
        metrics[model_name] = evaluate_model(models[model_name], X_test_subset, y_test_subset)

    return models, metrics

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
import numpy as np

#function to create ensemble model
def ensemble_model(models, X_test, y_test):
    # Initialize the prediction probabilities array
    y_pred_proba = np.zeros_like(y_test, dtype=float)
    y_pred = np.zeros_like(y_test, dtype=int)

    # Create masks based on loan_amount conditions
    mask0 = X_test['loan_amount'] < 10000
    mask1 = X_test['loan_amount'] > 75000
    mask2 = (~(mask0 | mask1))

    # Predict probabilities for different conditions
    y_pred_proba[mask0] = models['loan under 10000'].predict_proba(X_test[mask0])[:, 1]
    y_pred[mask0] = models['loan under 10000'].predict(X_test[mask0])

    y_pred_proba[mask1] = models['loan above 75000'].predict_proba(X_test[mask1])[:, 1]
    y_pred[mask1] = models['loan above 75000'].predict(X_test[mask1])

    y_pred_proba[mask2] = models['base_model for loan inbetween'].predict_proba(X_test[mask2])[:, 1]
    y_pred[mask2] = models['base_model for loan inbetween'].predict(X_test[mask2])

    # Calculate metrics
    roc_auc = roc_auc_score(y_test, y_pred_proba)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    return {
        "ROC AUC": roc_auc,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
    }

# %%
# compare base and ensemble model
models, metrics = train_and_evaluate_models(X_train, y_train, X_test, y_test)
ensemble_metrics = ensemble_model(models, X_test, y_test)
# Print ensemble metrics
print("Ensemble Model Metrics:")
print()
for metric, value in ensemble_metrics.items():
    print(f"{metric}: {value}")
# Out:
# Ensemble Model Metrics:
#
# ROC AUC: 0.9177545344525231
# Accuracy: 0.93795
# Precision: 0.9115969581749049
# Recall: 0.6451395896400942
# F1 Score: 0.7555643096316722

# %% [markdown]
# ### **Compare the base and ensemble models**

# %%
import matplotlib.pyplot as plt
import pandas as pd

def compare_models(base_model_metrics, ensemble_metrics):
    # Convert the metrics dictionaries to pandas DataFrames
    metrics_df = pd.DataFrame({'Base Model': base_model_metrics, 'Ensemble Model': ensemble_metrics})

    # Plot the metrics
    metrics_df.plot.bar(figsize=(10, 6), color=['#696969', '#4ecdc4'], rot=0)


    # Set plot labels and title
    plt.xlabel('Metrics')
    plt.ylabel('Scores')
    plt.title('Base Model vs Ensemble Model Metrics')
    plt.ylim(0, 1)  # Set y-axis limit for better comparison
    plt.legend(title='Models')

    # Show the plot
    plt.show()
compare_models(base_model_metrics, ensemble_metrics)

# %% [markdown]
# - The `ensemble model` is literally the same as the `base model`
# - To avoid complexities, we stick to the simple `base model`.

# %% [markdown]
# # MODEL BIAS ANALYSIS

# %% [markdown]
# ## **Feature Importance**

# %% [markdown]
# Here we are going to assess the importances of individual features using our models builtin feature importances feature.

# %%
_, model, __, y_pred,y_pred_proba = train_evaluate_model(X_train, y_train, X_test, y_test)
feature_importances = pd.DataFrame(model.feature_importances_).T
feature_importances.columns = model.feature_names_
feature_importances.T.sort_values(by=0, ascending=False)
# Out:
#                                    0
# age                        13.016914
# location                   11.836190
# interest_rate              11.036923
# loan_amount                10.664032
# total_loan_amount_per_job  10.344425
# location_class              8.990857
# salary                      5.675553
# remaining term              5.434454
# job                         4.315608
# job_location_interact       3.980637
# marital_status              3.725200
# outstanding_balance         3.506455
# number_of_defaults          2.760174
# gender                      2.750841
# is_employed                 1.812645
# loan_equal_5000             0.140362
# loan_>_75000                0.008730

# %% [markdown]
# ### Feature Importances Overview
#
# - **High Impact Features:**
#   - `age`
#   - `total_loan_amount_per_job`
#   - `interest_rate`
#   - `loan_amount`
#   - `location`
#
# - **Moderate Impact Features:**
#   - `salary`
#   - `remaining term`
#   - `job_location_interact`
#   - `location_class`
#   - `job`
#   - `Category`
#   - `marital_status`
#
# - **Lower Impact Features:**
#   - `outstanding_balance`
#   - `number_of_defaults`
#   - `gender`
#   - `is_employed`
#
# - **Minimal Impact Features:**
#   - `loan_equal_5000`
#   - `loan_>_75000`
#
# This overview shows how various features contribute to the model's performance, with some features having a significantly higher impact than others.

# %% [markdown]
# ## Confusion matrix
# We want to identify classes our model is failing misearably.

# %%
# Plot confusion 
plt.figure();
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(confusion_matrix=cm);
disp.plot(cmap=plt.cm.Blues);
plt.title('Confusion Matrix');
plt.show();

# %% [markdown]
# ### Confusion Matrix Interpretation
#
# - **High True Negatives (TN = 16737):** The model performs very well at correctly identifying non-defaulted loans.
# - **High True Positives (TP = 2016):** The model is also quite good at correctly identifying defaulted loans.
# - **False Positives (FP = 290):** There are relatively few false positives, indicating that the model doesn't often incorrectly identify non-defaulted loans as defaulted.
# - **False Negatives (FN = 957):** There is a moderate number of false negatives, meaning the model sometimes misses defaulted loans.
#
# ### Findings
#
# Overall, the model demonstrates high accuracy and specificity, meaning it is very good at correctly identifying non-defaulted loans. The precision is also quite high, indicating that when the model predicts a loan will default, it is usually correct. However, the recall is lower, suggesting that the model misses a significant number of defaulted loans. This trade-off between precision and recall is typical in many classification problems, and depending on the application

# %% [markdown]
# ### ROC AUC Analysis by Sensitive Features
#
# #### Objective:
# This code snippet is designed to analyze the performance of a machine learning model based on ROC AUC scores across various sensitive features. The goal is to understand how well the model predicts loan default status across different subgroups defined by these features and identify bias.
#
# #### Key Steps:
# 1. **Data Preparation:**
#    - The test data (`X_test`) is prepared by binning numerical features and mapping categorical features using predefined label encodings. This ensures consistency in data representation for analysis.
#
# 2. **Results Compilation:**
#    - A results DataFrame (`results_df`) is created to store:
#      - Actual loan default labels (`Actual`).
#      - Predicted probabilities of default (`y_pred_proba`).
#      - Sensitive features such as `gender`, `location`, `job`, `marital_status`, and numeric features like `loan_amount`, `salary`, `outstanding_balance`, etc.
#
# 3. **ROC AUC Analysis:**
#    - ROC AUC scores are computed for each subgroup defined by the sensitive features. This metric measures the model's ability to distinguish between default and non-default cases within each subgroup.
#
# 4. **Visualization:**
#    - The ROC AUC scores are visualized using bar plots for each sensitive feature. Each plot shows how well the model performs across different subgroups, helping identify which features have a significant impact on prediction accuracy.
#
# #### Meaning:
# - Higher ROC AUC scores indicate better model performance within a subgroup, suggesting the model's effectiveness in predicting loan default status for that particular segment of data.
# - Lower ROC AUC scores may highlight areas where the model performs less accurately, signaling potential biases or areas needing improvement in predictive capability.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

def plot_roc_auc_by_feature(results_df, sensitive_features):
    """
    Plot ROC AUC scores by different sensitive features.

    Parameters:
    - results_df (pd.DataFrame): DataFrame containing actual values, predicted probabilities, and features.
    - sensitive_features (list of str): List of features to analyze.
    """
    n_features = len(sensitive_features)
    fig, axes = plt.subplots(nrows=(n_features + 1) // 2, ncols=2, figsize=(16, 30))
    axes = axes.flatten()

    for i, feature in enumerate(sensitive_features):
        subgroups = results_df.groupby(feature, observed=True)
        roc_auc_scores = []
        print(f'feature: {feature}')
        print()
        for name, group in subgroups:
            if len(group['Actual'].unique()) <= 1:
                print(f'{name} of {feature} has 1 class of y')
                continue
            roc_auc = roc_auc_score(group['Actual'], group['y_pred_proba'])
            roc_auc_scores.append((name, roc_auc))
            print(f'category: {name} roc_auc: {roc_auc}')
            

        print('===========================================')

            
            

        roc_auc_df = pd.DataFrame(roc_auc_scores, columns=[feature, 'ROC AUC'])
        sns.barplot(data=roc_auc_df, x=feature, y='ROC AUC', ax=axes[i])
        axes[i].set_title(f'ROC AUC by {feature.capitalize()}')
        axes[i].set_ylim(0, 1)
        axes[i].set_xlabel(feature.capitalize())
        axes[i].set_ylabel('ROC AUC Score')
        for label in axes[i].get_xticklabels():
            label.set_rotation(45)
            label.set_ha('right')

        # Add text annotations for each bar
        for index, row in roc_auc_df.iterrows():
            axes[i].text(row.name, row['ROC AUC'], round(row['ROC AUC'], 2), color='black', ha="center")

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# Example usage
label_encodings_location = {v: k for k, v in label_encodings['location'].items()}
label_encodings_job = {v: k for k, v in label_encodings['job'].items()}

X_test_plot = X_test.copy()
X_test_plot['loan_amount'] = pd.cut(X_test_plot['loan_amount'], bins=np.arange(0, 300000, 10000))
X_test_plot['salary'] = pd.cut(X_test_plot['salary'], bins=np.arange(0, 10000, 1000))
X_test_plot['outstanding_balance'] = pd.cut(X_test_plot['outstanding_balance'], bins=np.arange(0, 300000, 20000))
X_test_plot['remaining_term'] = pd.cut(X_test_plot['remaining term'], bins=np.arange(0, 150, 20))
X_test_plot['age'] = pd.cut(X_test_plot['age'], bins=np.arange(0, 80, 10))
X_test_plot['location'] = X_test_plot['location'].map(label_encodings_location)
X_test_plot['job'] = X_test_plot['job'].map(ind_to_feature_job).astype('int').map(label_encodings_job)
X_test_plot['marital_status'] = X_test_plot['marital_status'].map({0: 'single', 1: 'married', 2: 'divorced'})
X_test_plot['gender'] = X_test_plot['gender'].map({1: "other", 0: "female", 2: 'male'})

results_df = pd.DataFrame({
    'Actual': y_test,
    'y_pred_proba': y_pred_proba,
    'gender': X_test_plot['gender'],
    'location': X_test_plot['location'],
    'job': X_test_plot['job'],
    'number_of_defaults': X_test_plot['number_of_defaults'],
    'location_class': X_test_plot['location_class'],
    'marital_status': X_test_plot['marital_status'],
    'loan_amount': X_test_plot['loan_amount'],
    'salary': X_test_plot['salary'],
    'outstanding_balance': X_test_plot['outstanding_balance'],
    'interest_rate': X_test_plot['interest_rate'],
    'remaining_term': X_test_plot['remaining_term'],
})

sensitive_features = ['gender', 'location', 'job', 'number_of_defaults', 'location_class',
                      'marital_status', 'loan_amount', 'salary', 'outstanding_balance', 'interest_rate', 'remaining_term']

plot_roc_auc_by_feature(results_df, sensitive_features)
# Out:
# feature: gender
#
# category: female roc_auc: 0.926056437379958
# category: male roc_auc: 0.9171262134826458
# category: other roc_auc: 0.9185736719215092
# ===========================================
# feature: location
#
# category: Beitbridge roc_auc: 0.9449523609359675
# category: Bulawayo roc_auc: 0.9625979505726342
# category: Chimanimani roc_auc: 0.9414750380386415
# category: Chipinge roc_auc: 0.9371448525443637
# category: Chiredzi roc_auc: 0.9163928837093975
# category: Chivhu roc_auc: 0.9400352733686066
# category: Gokwe roc_auc: 0.8996515679442508
# category: Gweru roc_auc: 0.9547806524184477
# category: Harare roc_auc: 0.8764224228427462
# category: Hwange roc_auc: 0.8153846153846154
# category: Kadoma roc_auc: 0.8908747573073753
# category: Kariba roc_auc: 0.8614718614718615
# category: Karoi roc_auc: 0.8397798481185268
# category: Kwekwe roc_auc: 0.8546921142427816
# category: Marondera roc_auc: 0.3
# category: Masvingo roc_auc: 0.7993640443309449
# category: Mutare roc_auc: 0.8482523576830902
# category: Nyanga roc_auc: 0.7893864013266999
# category: Plumtree roc_auc: 0.7641103262697612
# category: Redcliff roc_auc: 0.8501199040767387
# category: Rusape roc_auc: 0.7116996611378634
# category: Shurugwi roc_auc: 1.0
# category: Victoria Falls roc_auc: 0.8208762886597939
# category: Zvishavane roc_auc: 0.8540076335877863
# category: unknown roc_auc: 0.6923076923076923
# ===========================================
# feature: job
#
# category: Accountant roc_auc: 0.9491908651572517
# category: Data Analyst roc_auc: 0.9016542874905951
# category: Data Scientist roc_auc: 0.9768474426216315
# category: Doctor roc_auc: 0.9047223991681165
# category: Engineer roc_auc: 0.9161928543363974
# category: Lawyer roc_auc: 0.9833250620347395
# category: Nurse roc_auc: 0.9132250571152579
# category: Software Developer roc_auc: 0.9075060218202426
# category: Teacher roc_auc: 0.9273173735070731
# ===========================================
# feature: number_of_defaults
#
# category: 0 roc_auc: 0.916565898741711
# category: 1 roc_auc: 0.906682296901512
# category: 2 roc_auc: 0.8906547146147812
# ===========================================
# feature: location_class
#
# category: 0 roc_auc: 0.950593462107708
# category: 1 roc_auc: 0.8589798549030706
# ===========================================
# feature: marital_status
#
# category: divorced roc_auc: 0.948685408575562
# category: married roc_auc: 0.9220295073423029
# category: single roc_auc: 0.8711017059298408
# ===========================================
# feature: loan_amount
#
# category: (0, 10000] roc_auc: 0.9750036118152327
# category: (10000, 20000] roc_auc: 0.9049353355787612
# category: (20000, 30000] roc_auc: 0.9002786944436825
# category: (30000, 40000] roc_auc: 0.8844299484978814
# category: (40000, 50000] roc_auc: 0.913306402869001
# category: (50000, 60000] roc_auc: 0.9021165867421712
# category: (60000, 70000] roc_auc: 0.9359477124183007
# category: (70000, 80000] roc_auc: 1.0
# (80000, 90000] of loan_amount has 1 class of y
# category: (100000, 110000] roc_auc: 1.0
# (110000, 120000] of loan_amount has 1 class of y
# (120000, 130000] of loan_amount has 1 class of y
# category: (130000, 140000] roc_auc: 1.0
# (140000, 150000] of loan_amount has 1 class of y
# (150000, 160000] of loan_amount has 1 class of y
# category: (160000, 170000] roc_auc: 1.0
# category: (170000, 180000] roc_auc: 1.0
# (180000, 190000] of loan_amount has 1 class of y
# category: (190000, 200000] roc_auc: 1.0
# category: (210000, 220000] roc_auc: 1.0
# (220000, 230000] of loan_amount has 1 class of y
# (230000, 240000] of loan_amount has 1 class of y
# ===========================================
# feature: salary
#
# (0, 1000] of salary has 1 class of y
# category: (1000, 2000] roc_auc: 0.9448777431138842
# category: (2000, 3000] roc_auc: 0.9212670485358265
# category: (3000, 4000] roc_auc: 0.9058427496333539
# category: (4000, 5000] roc_auc: 0.8621937115038057
# category: (5000, 6000] roc_auc: 0.8988821138211383
# (6000, 7000] of salary has 1 class of y
# (7000, 8000] of salary has 1 class of y
# (8000, 9000] of salary has 1 class of y
# ===========================================
# feature: outstanding_balance
#
# category: (0, 20000] roc_auc: 0.9722222222222222
# category: (20000, 40000] roc_auc: 0.9216320865342008
# category: (40000, 60000] roc_auc: 0.9184797035005481
# category: (60000, 80000] roc_auc: 0.9069273156651797
# category: (80000, 100000] roc_auc: 0.7373737373737373
# (100000, 120000] of outstanding_balance has 1 class of y
# ===========================================
# feature: interest_rate
#
# 0.11 of interest_rate has 1 class of y
# 0.12 of interest_rate has 1 class of y
# 0.13 of interest_rate has 1 class of y
# category: 0.14 roc_auc: 0.9678571428571429
# category: 0.15 roc_auc: 0.9495890410958904
# category: 0.16 roc_auc: 0.9547715965626413
# category: 0.17 roc_auc: 0.9654207021791767
# category: 0.18 roc_auc: 0.9638951260654401
# category: 0.19 roc_auc: 0.9305566763115726
# category: 0.2 roc_auc: 0.881373182552504
# category: 0.21 roc_auc: 0.8763278957172311
# category: 0.22 roc_auc: 0.8639970889117378
# category: 0.23 roc_auc: 0.9265042971154218
# category: 0.24 roc_auc: 0.9456977516364672
# category: 0.25 roc_auc: 0.9360663288807001
# category: 0.26 roc_auc: 0.9584511023176936
# category: 0.27 roc_auc: 1.0
# category: 0.28 roc_auc: 1.0
# 0.29 of interest_rate has 1 class of y
# ===========================================
# feature: remaining_term
#
# category: (0, 20] roc_auc: 0.9869565217391305
# category: (20, 40] roc_auc: 0.9112504145936982
# category: (40, 60] roc_auc: 0.9245410531730396
# category: (60, 80] roc_auc: 0.9172961463018071
# category: (80, 100] roc_auc: 0.917148053059478
# category: (100, 120] roc_auc: 1.0
# ===========================================

# %% [markdown]
# ### Summary of ROC AUC Scores by Feature Categories
#
# #### Gender
# - **Female**: ROC AUC = 0.926
# - **Male**: ROC AUC = 0.917
# - **Other**: ROC AUC = 0.919
#
# * **Location** *(Biased)*
#     - Hwange (ROC AUC = 0.815) is significantly lower than other locations (e.g., Gokwe: 0.900, Karoi: 0.840).
#
# * **Job** *(No Bias)*
#     - All job categories show comparable ROC AUC scores (e.g., Lawyer: 0.983, Data Scientist: 0.977).
#
# * **Number of Defaults** *(No Bias)*
#     - ROC AUC scores for different default counts are within a similar range (e.g., 0 defaults: 0.917, 1 default: 0.907).
#
# * **Location Class** *(No Bias)*
#     - ROC AUC scores for location classes (e.g., Class 0: 0.951, Class 1: 0.859) show reasonable performance without significant bias.
#
# * **Marital Status** *(No Bias)*
#     - ROC AUC scores for marital statuses (e.g., Divorced: 0.949, Single: 0.871) exhibit consistent performance across categories.
#
# * **Loan Amount** *(Biased)*
#     - Extremely high ROC AUC scores in certain loan amount ranges (e.g., (70000, 80000]: 1.0, (100000, 110000]: 1.0), possibly indicating bias due to class imbalance.
#
# * **Salary** *(No Bias)*
#     - ROC AUC scores for salary ranges (e.g., (1000, 2000]: 0.945, (3000, 4000]: 0.908) show consistent predictive performance.
#
# * **Outstanding Balance** *(No Bias)*
#     - ROC AUC scores for outstanding balance categories (e.g., (0, 20000]: 0.968, (80000, 100000]: 0.747) are mostly consistent with some variation.
#
# * **Interest Rate** *(No Bias)*
#     - ROC AUC scores for interest rates (e.g., 0.14: 0.950, 0.27: 1.0) demonstrate consistent performance with no significant biases.
#
# * **Remaining Term** *(No Bias)*
#     - ROC AUC scores for remaining term categories (e.g., (0, 20]: 0.983, (100, 120]: 1.0) show consistent predictive ability without biases.

# %% [markdown]
# ## BIAS MITIGATION
# Here we want to try and find ways to mitigate the observed bias. We are going to try
# - Feature Engineering.
# - Data resampling to yield class balance.

# %% [markdown]
# ### Secondary Feature Engineering
#
#
# As have we seen that age, interest_rate, loan_amount, location, total_loan_amount_per_location have high importances, we are going to create new features on them.

# %%
from sklearn.preprocessing import PolynomialFeatures

# Function to create new features
def create_new_features(df):
    epsilon = 1e-8  # Small value to avoid division by zero
    df = df.copy()  # To avoid modifying the original DataFrame
    df['interest_rate_per_loan_amount'] = df['interest_rate'] / (df['total_loan_amount_per_job'] + epsilon)
    df['age_per_loan_amount'] = df['age'] / (df['total_loan_amount_per_job'] + epsilon)
    df['job_location_per_loan_amount'] = df['job_location_interact'] / (df['total_loan_amount_per_job'] + epsilon)
    df['loan_5000_and_loan_75000_interaction'] = df['loan_equal_5000'] * df['loan_>_75000']
    
    return df

# Create new features for training and test sets
X_train_1 = create_new_features(X_train)
X_test_1 = create_new_features(X_test)


_,model,__, ___,____ = train_evaluate_model(X_train_1, y_train, X_test_1, y_test, show_plots=True)
# Out:
# Optimal Threshold (ROC): 0.2633834634169782
# 0.9219036400725694

# %% [markdown]
# * Our score improved a little bit

# %% [markdown]
# ## Try resampling to balance classes
#
# ### Choice of sampling technique
#
# #### **UNDERSAMPLING**
#
# The chosen `undersampling` technique is **Tomek Links**, which is an under-sampling method designed to clarify the decision boundary between classes in imbalanced datasets. Tomek Links identify pairs of samples (one from each class) that are nearest neighbors to each other but belong to different classes.
#
# - It selectively removes samples near the decision boundary to improve class separation.
# - Effective for datasets where classes are densely packed or overlap.
#
# #### **OVERSAMPLING**
#
# The chosen `oversampling` technique is **SMOTE (Synthetic Minority Over-sampling Technique)**, which generates synthetic samples for the minority class based on the characteristics of existing minority samples.
#
# - It creates synthetic instances along the line segments joining minority class nearest neighbors, effectively increasing the representation of the minority class.
# - Suitable for addressing class imbalance by providing more diverse and representative training data for models.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks

# over_sampling with tomeklinks
tl = TomekLinks()
X_tl, y_tl = tl.fit_resample(X_train_1, y_train)
tomek_link_scores, model, __,___,____= train_evaluate_model(X_tl,y_tl, X_test_1, y_test)
print('tomeklink scores')
print()
print(tomek_link_scores)
print('=====================================')

sm = SMOTE(sampling_strategy='auto')
X_smote, y_smote = tl.fit_resample(X_train_1, y_train)

smote_scores, model, __ ,___, ____= train_evaluate_model(X_smote,y_smote, X_test_1, y_test)
print('smote scores')
print('=====================================')
print(smote_scores)
# Out:
# tomeklink scores
#
# {'Accuracy': 0.91745, 'Precision': 0.7259056732740943, 'Recall': 0.7144298688193743, 'F1 Score': 0.7201220545855229, 'ROC AUC': 0.9144701443786347}
# =====================================
# smote scores
# =====================================
# {'Accuracy': 0.91745, 'Precision': 0.7259056732740943, 'Recall': 0.7144298688193743, 'F1 Score': 0.7201220545855229, 'ROC AUC': 0.9144701443786347}

# %% [markdown]
# ### CLUSTERING
# #### APPLYING ELBOW METHOD TO FIND THE BEST NUMBER OF CLUSTERS

# %%
inertias = []

for i in range(2,16):
    kmeans = KMeans(n_clusters=i, random_state=0).fit(X_train)
    inertias.append(kmeans.inertia_)

plt.figure(figsize=(10,5))
plt.title('ELBOW METHOD')
plt.plot(np.arange(2,16),inertias, marker='o', lw=2, color='steelblue');

# %% [markdown]
# * K = 8 seems more as the elbow. Try K = 8 and around

# %%
## APPLYING K-MEANS TO THE DATASET 


kmeans = KMeans(n_clusters=k, random_state=0).fit(X_train)
X_train_1['cluster'] = kmeans.labels_
X_test_1['cluster'] = kmeans.predict(X_test)

_,model,__, ___,____ = train_evaluate_model(X_train_1, y_train, X_test_1, y_test, show_plots=True)
# Out:
# Optimal Threshold (ROC): 0.25199836158384226
# 0.9220094453969756

# %% [markdown]
# * **Model improved by 0.001**

# %% [markdown]
# ### **SAMPLING FINDINGS**
#
# Like most sampling techniques with boosting algorithms. Both undersampling(tomek) and oversampling(smote) did not improve our model. Therefore we will stick to our base model.

# %% [markdown]
# ### Explanation of Model Predictions
#
# The model performs well overall, with high ROC AUC scores and no significant bias for features like gender, job, and salary. However, there is noticeable bias in the location and loan amount features, with extreme ROC AUC scores in some categories suggesting potential class imbalance issues.

# %% [markdown]
# ### Model Limitations
#
# The model has several limitations that should be considered:
#
# * **Location Bias:**  Performance is notably weaker in Hwange.
# * **Loan Amount Bias:** Potential bias exists for specific loan amounts.
# * **Class Imbalance:** The dataset's extreme imbalance may affect the model's ability to predict defaults accurately for smaller loan amounts.
# * **Generalization:**  The model's accuracy may not generalize well to data significantly different from the training data.

# %% [markdown]
# ### Potential enhancements or future directions for model improvement.
#
# * **Address Bias:**
#     * Gather more data from Hwange or develop specialized models for this location.
#     * Explore resampling techniques (e.g., SMOTE) or cost-sensitive learning to mitigate loan amount bias.
# * **Feature Engineering:**  Create new features or transform existing ones to capture more predictive information.
# * **Hyperparameter Tuning:** Fine-tune CatBoost's parameters for optimal performance.
# * **Alternative Models:** Experiment with other algorithms like XGBoost or LightGBM.

# %% [markdown]
# ### Business Implications
#
# The findings have significant implications for the business:
#
# **Fairness and Risk Management:**  Addressing potential biases is crucial to ensure fair treatment of borrowers and mitigate financial risks.
# * **Targeted Interventions:** Develop tailored loan products or interventions for specific customer segments, such as those in Hwange.
# * **Model Monitoring:** Continuous monitoring and retraining are essential to maintain the model's accuracy and fairness over time.

# %% [markdown]
# # DATA DRIFT
#
# A class named **DataDriftMonitor** has been implemented in a separate script `data_drift.py` to handle data drift detection.
#
# Data drift detection monitors changes in data to ensure model performance. This section implements the KS test for numerical features and PSI for both numerical and categorical features, including visualizations for clarity.
#
# ### Data Drift Detection metrics to be used
#
# #### 1. Population Stability Index (PSI)
#
# **Population Stability Index (PSI)** measures the change in distribution of a feature over time. It is useful for detecting data drift, where significant changes in feature distribution might affect model performance.
#
# - **For Numerical Features**:
#   - **Bin Creation**: Scale and bin the feature values.
#   - **Calculation**: Compare the proportions of observations in each bin between the training and new data.
#   - **Interpretation**:
#     - **PSI < 0.1**: Little or no change.
#     - **0.1 ≤ PSI < 0.25**: Moderate change.
#     - **PSI ≥ 0.25**: Significant change.
#
# - **For Categorical Features**:
#   - **Distribution Calculation**: Compute the proportion of each category in both training and new data.
#   - **Calculation**: Compare these proportions to detect shifts.
#   - **Interpretation**: Similar thresholds apply as for numerical features, with PSI values indicating the extent of drift.
#
# #### 2. Kolmogorov-Smirnov (KS) Test
#
# **KS Test** compares the distributions of a numerical feature between two datasets. It measures the maximum difference between the cumulative distribution functions (CDFs) of the training and new data.
#
# - **Calculation**:
#   - **KS Statistic**: The maximum absolute difference between CDFs.
#   - **P-Value**: Probability of observing the KS statistic under the null hypothesis of no drift.
#
# - **Interpretation**:
#   - **Higher KS Statistic**: Indicates a larger difference between distributions, suggesting potential drift.
#   - **P-Value**: If significantly small, it supports the presence of drift.
#
# These metrics help monitor and detect data drift, ensuring that your model remains effective as the underlying data evolves.

# %%
# import our custom made DataDriftMonitor class
import data_drift 
importlib.reload(data_drift)
from data_drift import DataDriftMonitor

#instantiate our monitor with our training data
monitor = DataDriftMonitor(X_train)

# test on our test data
monitor.transform(X_test);
# Out:
# KS Test Results: {'Unnamed: 0': 0.38703257186352613, 'loan_amount': 0.5966906872515435, 'number_of_defaults': 0.6046245156692129, 'outstanding_balance': 0.5164578947819605, 'interest_rate': 0.9663201625214487, 'age': 0.4340766408712714, 'number_of_defaults.1': 0.6046245156692129, 'salary': 0.39355705681045416, 'age.1': 0.4340766408712714}
# PSI Results (Numeric Features): {'Unnamed: 0': 23.025697304268473, 'loan_amount': 0.0, 'number_of_defaults': 0.00016505378574296052, 'outstanding_balance': 23.025697304268473, 'interest_rate': 0.27820638834347183, 'age': 0.0, 'number_of_defaults.1': 0.00016505378574296052, 'salary': 0.0, 'age.1': 0.0}
# PSI Results (Categorical Features): {'job': 0.0008487561376096561, 'location': 0.03359121531795531, 'marital_status': 4.496890812284985e-05, 'gender': 0.0008035400434662412}

# %% [markdown]
# ### Key Findings
# - KS Test: All p-values are above 0.05, indicating no significant differences in the distributions of numerical features between the training and new data.
# - PSI: High PSI values for outstanding_balance (23.03) and remaining term (23.03) suggest significant drift in these features.
#
# ### Importance of Monitoring Data Drift
#
# Monitoring data drift is crucial for maintaining model performance for several reasons:
#
# 1. **Maintains Accuracy**: Ensures the model remains accurate as data distributions change over time.
# 2. **Addresses Concept Drift**: Detects shifts in underlying relationships between features and the target variable.
# 3. **Prevents Degradation**: Helps identify and address performance issues before they impact the model significantly.
# 4. **Enhances Reliability**: Demonstrates the robustness and dependability of the model in dynamic environments.
# 5. **Supports Continuous Improvement**: Allows iterative improvements by adapting to new data trends.
# 6. **Adapts to Real-World Changes**: Ensures the model stays relevant as real-world conditions evolve.
#
# Regular monitoring of data drift helps keep the model accurate and relevant, improving overall performance and robustness.

# %% [markdown]
# # CREATE A PIPELINE

# %% [markdown]
# Set Up the Machine Learning Pipeline:
#
# - Use custom data transformation classes to preprocess the data.
# - Use the custom data drift detection class to monitor model perfomance and compatibility.
# - Integrate the CatBoostClassifier into the pipeline for classification tasks.
#
# Train the Model:
#
# - Fit the pipeline to the training data, applying all transformations and training the classifier.
#
# Evaluate the Model:
#
# - Predict probabilities on the test set.
# - Have the roc curve plot to assess the perfomance

# %%
import importlib
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
import pipeline_process
import data_drift
importlib.reload(pipeline_process)
importlib.reload(data_drift)
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split

# Data Preparation
X = df1.drop(columns=['Loan Status', 'disbursemet_date', 'currency', 'country'])
y = df1['Loan Status'].map({'Did not default': 0, 'Defaulted': 1}).astype('int')
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=87)






# Identify numerical and categorical columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X.select_dtypes(include=['object']).columns

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ]
)

# Model and Pipeline Setup
clf = CatBoostClassifier(learning_rate = 0.07)
pipeline = Pipeline(steps=[
    # ('preprocessor', preprocessor),
    ('data_drift', data_drift.DataDriftMonitor(X_train)),
    ('transformer', pipeline_process.DataTransformer(X_train, y_train)),
    ('transformer1', pipeline_process.Predict_Marital()),
    
    ('classifier', clf)
])

# Fit the pipeline (this will also train Predict_Marital)
model = pipeline.fit(X_train, y_train)
print()
# Predict probabilities
P = pipeline.predict_proba(X_val)[:,1]
roc_auc = roc_auc_score(y_val, P)
print(f'ROC AUC: {roc_auc:.2f}')



# Calculate ROC Curve
fpr, tpr, thresholds = roc_curve(y_val, P)
# 
# Plot ROC Curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)

plt.show()
# Out:
# Predict_Marital Model Score: 0.9108917279648987
# 0:	learn: 0.6244092	total: 24.7ms	remaining: 24.7s
# 1:	learn: 0.5682372	total: 53.7ms	remaining: 26.8s
# 2:	learn: 0.5201141	total: 79.4ms	remaining: 26.4s
# 3:	learn: 0.4843992	total: 100ms	remaining: 24.9s
# 4:	learn: 0.4523469	total: 124ms	remaining: 24.7s
# 5:	learn: 0.4256958	total: 145ms	remaining: 24.1s
# 6:	learn: 0.4040094	total: 166ms	remaining: 23.6s
# 7:	learn: 0.3826382	total: 196ms	remaining: 24.3s
# 8:	learn: 0.3656568	total: 223ms	remaining: 24.6s
# 9:	learn: 0.3517384	total: 251ms	remaining: 24.9s
# 10:	learn: 0.3384637	total: 277ms	remaining: 24.9s
# 11:	learn: 0.3276685	total: 300ms	remaining: 24.7s
# 12:	learn: 0.3183062	total: 327ms	remaining: 24.8s
# 13:	learn: 0.3108760	total: 455ms	remaining: 32.1s
# 14:	learn: 0.3041553	total: 532ms	remaining: 34.9s
# 15:	learn: 0.2975288	total: 573ms	remaining: 35.2s
# 16:	learn: 0.2926856	total: 601ms	remaining: 34.7s
# 17:	learn: 0.2881748	total: 626ms	remaining: 34.2s
# 18:	learn: 0.2842563	total: 658ms	remaining: 34s
# 19:	learn: 0.2807247	total: 698ms	remaining: 34.2s
# 20:	learn: 0.2772213	total: 812ms	remaining: 37.9s
# 21:	learn: 0.2737338	total: 859ms	remaining: 38.2s
# 22:	learn: 0.2716222	total: 897ms	remaining: 38.1s
# 23:	learn: 0.2689406	total: 925ms	remaining: 37.6s
# 24:	learn: 0.2668167	total: 947ms	remaining: 36.9s
# 25:	learn: 0.2645799	total: 974ms	remaining: 36.5s
# 26:	learn: 0.2623805	total: 1s	remaining: 36.2s
# 27:	learn: 0.2603010	total: 1.08s	remaining: 37.4s
# 28:	learn: 0.2583841	total: 1.23s	remaining: 41s
# 29:	learn: 0.2566500	total: 1.27s	remaining: 41.2s
# 30:	learn: 0.2552318	total: 1.3s	remaining: 40.7s
# 31:	learn: 0.2535284	total: 1.33s	remaining: 40.2s
# 32:	learn: 0.2526141	total: 1.35s	remaining: 39.6s
# 33:	learn: 0.2513473	total: 1.38s	remaining: 39.1s
# 34:	learn: 0.2500740	total: 1.5s	remaining: 41.3s
# 35:	learn: 0.2489689	total: 1.55s	remaining: 41.7s
# 36:	learn: 0.2478667	total: 1.58s	remaining: 41.3s
# 37:	learn: 0.2471221	total: 1.61s	remaining: 40.7s
# 38:	learn: 0.2458895	total: 1.63s	remaining: 40.1s
# 39:	learn: 0.2451006	total: 1.68s	remaining: 40.4s
# 40:	learn: 0.2443414	total: 1.81s	remaining: 42.5s
# 41:	learn: 0.2435412	total: 1.84s	remaining: 41.9s
# 42:	learn: 0.2428025	total: 1.88s	remaining: 41.9s
# 43:	learn: 0.2420106	total: 1.9s	remaining: 41.4s
# 44:	learn: 0.2413635	total: 1.93s	remaining: 40.9s
# 45:	learn: 0.2407698	total: 1.95s	remaining: 40.4s
# 46:	learn: 0.2401448	total: 1.97s	remaining: 39.9s
# 47:	learn: 0.2397049	total: 1.99s	remaining: 39.5s
# 48:	learn: 0.2390786	total: 2.02s	remaining: 39.2s
# 49:	learn: 0.2385434	total: 2.04s	remaining: 38.8s
# 50:	learn: 0.2379743	total: 2.07s	remaining: 38.5s
# 51:	learn: 0.2373715	total: 2.1s	remaining: 38.2s
# 52:	learn: 0.2368124	total: 2.12s	remaining: 37.8s
# 53:	learn: 0.2364306	total: 2.14s	remaining: 37.5s
# 54:	learn: 0.2359622	total: 2.16s	remaining: 37.2s
# 55:	learn: 0.2354140	total: 2.2s	remaining: 37s
# 56:	learn: 0.2347939	total: 2.34s	remaining: 38.7s
# 57:	learn: 0.2340075	total: 2.41s	remaining: 39.1s
# 58:	learn: 0.2333500	total: 2.44s	remaining: 38.9s
# 59:	learn: 0.2328056	total: 2.46s	remaining: 38.5s
# 60:	learn: 0.2324623	total: 2.48s	remaining: 38.3s
# 61:	learn: 0.2321159	total: 2.51s	remaining: 38s
# 62:	learn: 0.2317536	total: 2.54s	remaining: 37.8s
# 63:	learn: 0.2311761	total: 2.57s	remaining: 37.6s
# 64:	learn: 0.2306542	total: 2.6s	remaining: 37.5s
# 65:	learn: 0.2302337	total: 2.63s	remaining: 37.2s
# 66:	learn: 0.2298019	total: 2.65s	remaining: 36.9s
# 67:	learn: 0.2294140	total: 2.68s	remaining: 36.7s
# 68:	learn: 0.2290040	total: 2.7s	remaining: 36.5s
# 69:	learn: 0.2286317	total: 2.73s	remaining: 36.2s
# 70:	learn: 0.2283071	total: 2.75s	remaining: 36s
# 71:	learn: 0.2279661	total: 2.77s	remaining: 35.7s
# 72:	learn: 0.2276030	total: 2.96s	remaining: 37.5s
# 73:	learn: 0.2271808	total: 3.02s	remaining: 37.8s
# 74:	learn: 0.2267895	total: 3.05s	remaining: 37.6s
# 75:	learn: 0.2263981	total: 3.08s	remaining: 37.4s
# 76:	learn: 0.2261660	total: 3.11s	remaining: 37.3s
# 77:	learn: 0.2258123	total: 3.14s	remaining: 37.1s
# 78:	learn: 0.2255727	total: 3.2s	remaining: 37.4s
# 79:	learn: 0.2254164	total: 3.28s	remaining: 37.7s
# 80:	learn: 0.2251499	total: 3.32s	remaining: 37.7s
# 81:	learn: 0.2247403	total: 3.35s	remaining: 37.6s
# 82:	learn: 0.2243383	total: 3.38s	remaining: 37.4s
# 83:	learn: 0.2240601	total: 3.51s	remaining: 38.3s
# 84:	learn: 0.2238011	total: 3.59s	remaining: 38.7s
# 85:	learn: 0.2236195	total: 3.63s	remaining: 38.6s
# 86:	learn: 0.2232591	total: 3.66s	remaining: 38.4s
# 87:	learn: 0.2229677	total: 3.69s	remaining: 38.2s
# 88:	learn: 0.2227155	total: 3.71s	remaining: 38s
# 89:	learn: 0.2224263	total: 3.74s	remaining: 37.8s
# 90:	learn: 0.2220887	total: 3.76s	remaining: 37.6s
# 91:	learn: 0.2216972	total: 3.79s	remaining: 37.4s
# 92:	learn: 0.2214725	total: 3.82s	remaining: 37.3s
# 93:	learn: 0.2211810	total: 3.85s	remaining: 37.1s
# 94:	learn: 0.2208681	total: 3.87s	remaining: 36.9s
# 95:	learn: 0.2206250	total: 3.9s	remaining: 36.7s
# 96:	learn: 0.2204146	total: 3.92s	remaining: 36.5s
# 97:	learn: 0.2202878	total: 3.94s	remaining: 36.3s
# 98:	learn: 0.2201210	total: 3.96s	remaining: 36s
# 99:	learn: 0.2200063	total: 3.98s	remaining: 35.9s
# 100:	learn: 0.2198119	total: 4.09s	remaining: 36.4s
# 101:	learn: 0.2196704	total: 4.19s	remaining: 36.9s
# 102:	learn: 0.2194322	total: 4.22s	remaining: 36.8s
# 103:	learn: 0.2192049	total: 4.25s	remaining: 36.7s
# 104:	learn: 0.2189801	total: 4.28s	remaining: 36.5s
# 105:	learn: 0.2187182	total: 4.3s	remaining: 36.3s
# 106:	learn: 0.2184818	total: 4.32s	remaining: 36.1s
# 107:	learn: 0.2183004	total: 4.35s	remaining: 35.9s
# 108:	learn: 0.2181407	total: 4.38s	remaining: 35.9s
# 109:	learn: 0.2179822	total: 4.41s	remaining: 35.7s
# 110:	learn: 0.2177383	total: 4.43s	remaining: 35.5s
# 111:	learn: 0.2175391	total: 4.46s	remaining: 35.4s
# 112:	learn: 0.2173218	total: 4.48s	remaining: 35.2s
# 113:	learn: 0.2171230	total: 4.5s	remaining: 35s
# 114:	learn: 0.2169706	total: 4.53s	remaining: 34.8s
# 115:	learn: 0.2167876	total: 4.55s	remaining: 34.7s
# 116:	learn: 0.2166576	total: 4.7s	remaining: 35.4s
# 117:	learn: 0.2164969	total: 4.76s	remaining: 35.6s
# 118:	learn: 0.2162229	total: 4.78s	remaining: 35.4s
# 119:	learn: 0.2161074	total: 4.8s	remaining: 35.2s
# 120:	learn: 0.2159071	total: 4.83s	remaining: 35.1s
# 121:	learn: 0.2157597	total: 4.85s	remaining: 34.9s
# 122:	learn: 0.2155486	total: 4.88s	remaining: 34.8s
# 123:	learn: 0.2153280	total: 4.9s	remaining: 34.6s
# 124:	learn: 0.2151178	total: 4.92s	remaining: 34.5s
# 125:	learn: 0.2148696	total: 5.02s	remaining: 34.8s
# 126:	learn: 0.2147172	total: 5.06s	remaining: 34.8s
# 127:	learn: 0.2144501	total: 5.1s	remaining: 34.8s
# 128:	learn: 0.2142166	total: 5.13s	remaining: 34.6s
# 129:	learn: 0.2140189	total: 5.15s	remaining: 34.5s
# 130:	learn: 0.2138714	total: 5.22s	remaining: 34.7s
# 131:	learn: 0.2137234	total: 5.34s	remaining: 35.1s
# 132:	learn: 0.2135822	total: 5.37s	remaining: 35s
# 133:	learn: 0.2134430	total: 5.39s	remaining: 34.9s
# 134:	learn: 0.2133362	total: 5.42s	remaining: 34.7s
# 135:	learn: 0.2132294	total: 5.44s	remaining: 34.6s
# 136:	learn: 0.2130098	total: 5.46s	remaining: 34.4s
# 137:	learn: 0.2127986	total: 5.49s	remaining: 34.3s
# 138:	learn: 0.2126800	total: 5.51s	remaining: 34.1s
# 139:	learn: 0.2125633	total: 5.54s	remaining: 34s
# 140:	learn: 0.2123674	total: 5.63s	remaining: 34.3s
# 141:	learn: 0.2122017	total: 5.68s	remaining: 34.3s
# 142:	learn: 0.2121048	total: 5.72s	remaining: 34.3s
# 143:	learn: 0.2119288	total: 5.75s	remaining: 34.2s
# 144:	learn: 0.2117265	total: 5.8s	remaining: 34.2s
# 145:	learn: 0.2115881	total: 5.95s	remaining: 34.8s
# 146:	learn: 0.2114397	total: 6s	remaining: 34.8s
# 147:	learn: 0.2113448	total: 6.02s	remaining: 34.7s
# 148:	learn: 0.2111455	total: 6.04s	remaining: 34.5s
# 149:	learn: 0.2109760	total: 6.07s	remaining: 34.4s
# 150:	learn: 0.2107949	total: 6.09s	remaining: 34.2s
# 151:	learn: 0.2106440	total: 6.11s	remaining: 34.1s
# 152:	learn: 0.2105307	total: 6.13s	remaining: 34s
# 153:	learn: 0.2104252	total: 6.16s	remaining: 33.8s
# 154:	learn: 0.2102773	total: 6.19s	remaining: 33.7s
# 155:	learn: 0.2101889	total: 6.21s	remaining: 33.6s
# 156:	learn: 0.2100488	total: 6.23s	remaining: 33.5s
# 157:	learn: 0.2099207	total: 6.26s	remaining: 33.4s
# 158:	learn: 0.2097767	total: 6.29s	remaining: 33.2s
# 159:	learn: 0.2096528	total: 6.31s	remaining: 33.1s
# 160:	learn: 0.2095489	total: 6.33s	remaining: 33s
# 161:	learn: 0.2094351	total: 6.35s	remaining: 32.9s
# 162:	learn: 0.2093249	total: 6.47s	remaining: 33.2s
# 163:	learn: 0.2092165	total: 6.55s	remaining: 33.4s
# 164:	learn: 0.2090685	total: 6.58s	remaining: 33.3s
# 165:	learn: 0.2089789	total: 6.61s	remaining: 33.2s
# 166:	learn: 0.2088429	total: 6.63s	remaining: 33.1s
# 167:	learn: 0.2087060	total: 6.65s	remaining: 32.9s
# 168:	learn: 0.2085697	total: 6.67s	remaining: 32.8s
# 169:	learn: 0.2084687	total: 6.71s	remaining: 32.8s
# 170:	learn: 0.2083601	total: 6.84s	remaining: 33.2s
# 171:	learn: 0.2082226	total: 6.9s	remaining: 33.2s
# 172:	learn: 0.2081238	total: 6.92s	remaining: 33.1s
# 173:	learn: 0.2079834	total: 6.96s	remaining: 33s
# 174:	learn: 0.2078948	total: 7.06s	remaining: 33.3s
# 175:	learn: 0.2077030	total: 7.17s	remaining: 33.6s
# 176:	learn: 0.2075459	total: 7.19s	remaining: 33.4s
# 177:	learn: 0.2073825	total: 7.22s	remaining: 33.3s
# 178:	learn: 0.2073021	total: 7.24s	remaining: 33.2s
# 179:	learn: 0.2072414	total: 7.27s	remaining: 33.1s
# 180:	learn: 0.2071393	total: 7.29s	remaining: 33s
# 181:	learn: 0.2070616	total: 7.31s	remaining: 32.9s
# 182:	learn: 0.2069274	total: 7.33s	remaining: 32.7s
# 183:	learn: 0.2067976	total: 7.46s	remaining: 33.1s
# 184:	learn: 0.2067038	total: 7.51s	remaining: 33.1s
# 185:	learn: 0.2065884	total: 7.54s	remaining: 33s
# 186:	learn: 0.2064700	total: 7.56s	remaining: 32.9s
# 187:	learn: 0.2063787	total: 7.61s	remaining: 32.9s
# 188:	learn: 0.2062930	total: 7.77s	remaining: 33.3s
# 189:	learn: 0.2062363	total: 7.81s	remaining: 33.3s
# 190:	learn: 0.2060870	total: 7.84s	remaining: 33.2s
# 191:	learn: 0.2059690	total: 7.87s	remaining: 33.1s
# 192:	learn: 0.2058705	total: 7.89s	remaining: 33s
# 193:	learn: 0.2057903	total: 7.91s	remaining: 32.9s
# 194:	learn: 0.2056529	total: 7.93s	remaining: 32.8s
# 195:	learn: 0.2055812	total: 7.96s	remaining: 32.7s
# 196:	learn: 0.2054293	total: 7.99s	remaining: 32.6s
# 197:	learn: 0.2053542	total: 8.02s	remaining: 32.5s
# 198:	learn: 0.2052028	total: 8.04s	remaining: 32.4s
# 199:	learn: 0.2051266	total: 8.07s	remaining: 32.3s
# 200:	learn: 0.2050555	total: 8.1s	remaining: 32.2s
# 201:	learn: 0.2049710	total: 8.12s	remaining: 32.1s
# 202:	learn: 0.2048979	total: 8.14s	remaining: 32s
# 203:	learn: 0.2048138	total: 8.16s	remaining: 31.9s
# 204:	learn: 0.2047327	total: 8.2s	remaining: 31.8s
# 205:	learn: 0.2046144	total: 8.34s	remaining: 32.1s
# 206:	learn: 0.2045108	total: 8.41s	remaining: 32.2s
# 207:	learn: 0.2043745	total: 8.44s	remaining: 32.1s
# 208:	learn: 0.2042920	total: 8.47s	remaining: 32.1s
# 209:	learn: 0.2042089	total: 8.51s	remaining: 32s
# 210:	learn: 0.2040535	total: 8.54s	remaining: 31.9s
# 211:	learn: 0.2039446	total: 8.57s	remaining: 31.9s
# 212:	learn: 0.2038175	total: 8.6s	remaining: 31.8s
# 213:	learn: 0.2037178	total: 8.73s	remaining: 32.1s
# 214:	learn: 0.2036292	total: 8.79s	remaining: 32.1s
# 215:	learn: 0.2035486	total: 8.83s	remaining: 32s
# 216:	learn: 0.2034319	total: 8.86s	remaining: 32s
# 217:	learn: 0.2033647	total: 8.88s	remaining: 31.9s
# 218:	learn: 0.2033039	total: 9s	remaining: 32.1s
# 219:	learn: 0.2032055	total: 9.15s	remaining: 32.4s
# 220:	learn: 0.2031183	total: 9.19s	remaining: 32.4s
# 221:	learn: 0.2030160	total: 9.22s	remaining: 32.3s
# 222:	learn: 0.2029148	total: 9.25s	remaining: 32.2s
# 223:	learn: 0.2028655	total: 9.28s	remaining: 32.1s
# 224:	learn: 0.2027717	total: 9.31s	remaining: 32.1s
# 225:	learn: 0.2026587	total: 9.47s	remaining: 32.4s
# 226:	learn: 0.2026072	total: 9.52s	remaining: 32.4s
# 227:	learn: 0.2025250	total: 9.55s	remaining: 32.3s
# 228:	learn: 0.2024577	total: 9.58s	remaining: 32.3s
# 229:	learn: 0.2023530	total: 9.65s	remaining: 32.3s
# 230:	learn: 0.2022499	total: 9.86s	remaining: 32.8s
# 231:	learn: 0.2021673	total: 9.89s	remaining: 32.8s
# 232:	learn: 0.2021046	total: 9.92s	remaining: 32.7s
# 233:	learn: 0.2020301	total: 9.95s	remaining: 32.6s
# 234:	learn: 0.2019719	total: 9.98s	remaining: 32.5s
# 235:	learn: 0.2018894	total: 10s	remaining: 32.4s
# 236:	learn: 0.2018282	total: 10s	remaining: 32.3s
# 237:	learn: 0.2017169	total: 10.1s	remaining: 32.2s
# 238:	learn: 0.2016378	total: 10.1s	remaining: 32.1s
# 239:	learn: 0.2015316	total: 10.1s	remaining: 32.1s
# 240:	learn: 0.2014581	total: 10.2s	remaining: 32s
# 241:	learn: 0.2013946	total: 10.2s	remaining: 31.9s
# 242:	learn: 0.2013481	total: 10.2s	remaining: 31.8s
# 243:	learn: 0.2012855	total: 10.2s	remaining: 31.7s
# 244:	learn: 0.2012448	total: 10.3s	remaining: 31.6s
# 245:	learn: 0.2011806	total: 10.3s	remaining: 31.5s
# 246:	learn: 0.2010897	total: 10.3s	remaining: 31.5s
# 247:	learn: 0.2009941	total: 10.4s	remaining: 31.5s
# 248:	learn: 0.2009448	total: 10.5s	remaining: 31.8s
# 249:	learn: 0.2008652	total: 10.6s	remaining: 31.8s
# 250:	learn: 0.2007611	total: 10.6s	remaining: 31.7s
# 251:	learn: 0.2006385	total: 10.7s	remaining: 31.6s
# 252:	learn: 0.2005059	total: 10.7s	remaining: 31.5s
# 253:	learn: 0.2004499	total: 10.7s	remaining: 31.5s
# 254:	learn: 0.2003987	total: 10.7s	remaining: 31.4s
# 255:	learn: 0.2003393	total: 10.8s	remaining: 31.3s
# 256:	learn: 0.2002287	total: 10.8s	remaining: 31.3s
# 257:	learn: 0.2001394	total: 10.8s	remaining: 31.2s
# 258:	learn: 0.2000430	total: 10.9s	remaining: 31.1s
# 259:	learn: 0.1999716	total: 10.9s	remaining: 31s
# 260:	learn: 0.1998759	total: 10.9s	remaining: 31s
# 261:	learn: 0.1998322	total: 11.1s	remaining: 31.3s
# 262:	learn: 0.1997533	total: 11.2s	remaining: 31.3s
# 263:	learn: 0.1996655	total: 11.2s	remaining: 31.2s
# 264:	learn: 0.1996514	total: 11.2s	remaining: 31.1s
# 265:	learn: 0.1995975	total: 11.3s	remaining: 31.1s
# 266:	learn: 0.1995904	total: 11.3s	remaining: 31s
# 267:	learn: 0.1995326	total: 11.3s	remaining: 30.9s
# 268:	learn: 0.1994690	total: 11.4s	remaining: 30.9s
# 269:	learn: 0.1994036	total: 11.5s	remaining: 31s
# 270:	learn: 0.1993376	total: 11.5s	remaining: 30.9s
# 271:	learn: 0.1993173	total: 11.5s	remaining: 30.9s
# 272:	learn: 0.1992667	total: 11.6s	remaining: 30.8s
# 273:	learn: 0.1992326	total: 11.6s	remaining: 30.7s
# 274:	learn: 0.1991399	total: 11.6s	remaining: 30.7s
# 275:	learn: 0.1990914	total: 11.7s	remaining: 30.6s
# 276:	learn: 0.1990363	total: 11.7s	remaining: 30.5s
# 277:	learn: 0.1989742	total: 11.9s	remaining: 30.8s
# 278:	learn: 0.1988476	total: 11.9s	remaining: 30.7s
# 279:	learn: 0.1987482	total: 11.9s	remaining: 30.7s
# 280:	learn: 0.1986602	total: 12s	remaining: 30.6s
# 281:	learn: 0.1985994	total: 12s	remaining: 30.6s
# 282:	learn: 0.1985063	total: 12.2s	remaining: 31s
# 283:	learn: 0.1983978	total: 12.3s	remaining: 31s
# 284:	learn: 0.1982887	total: 12.3s	remaining: 30.9s
# 285:	learn: 0.1982581	total: 12.4s	remaining: 30.9s
# 286:	learn: 0.1981927	total: 12.4s	remaining: 30.8s
# 287:	learn: 0.1981207	total: 12.4s	remaining: 30.8s
# 288:	learn: 0.1980318	total: 12.6s	remaining: 31.1s
# 289:	learn: 0.1979483	total: 12.8s	remaining: 31.3s
# 290:	learn: 0.1979399	total: 12.8s	remaining: 31.3s
# 291:	learn: 0.1978783	total: 12.9s	remaining: 31.3s
# 292:	learn: 0.1978376	total: 13.2s	remaining: 31.8s
# 293:	learn: 0.1977827	total: 13.3s	remaining: 31.9s
# 294:	learn: 0.1977224	total: 13.3s	remaining: 31.8s
# 295:	learn: 0.1976273	total: 13.3s	remaining: 31.7s
# 296:	learn: 0.1975706	total: 13.4s	remaining: 31.6s
# 297:	learn: 0.1974800	total: 13.4s	remaining: 31.6s
# 298:	learn: 0.1974743	total: 13.5s	remaining: 31.6s
# 299:	learn: 0.1974190	total: 13.5s	remaining: 31.5s
# 300:	learn: 0.1973839	total: 13.5s	remaining: 31.4s
# 301:	learn: 0.1973152	total: 13.6s	remaining: 31.4s
# 302:	learn: 0.1972553	total: 13.9s	remaining: 32s
# 303:	learn: 0.1971355	total: 14s	remaining: 32.1s
# 304:	learn: 0.1970620	total: 14.1s	remaining: 32s
# 305:	learn: 0.1970089	total: 14.1s	remaining: 32s
# 306:	learn: 0.1970027	total: 14.1s	remaining: 31.9s
# 307:	learn: 0.1969141	total: 14.2s	remaining: 31.8s
# 308:	learn: 0.1968339	total: 14.3s	remaining: 32s
# 309:	learn: 0.1968025	total: 14.5s	remaining: 32.3s
# 310:	learn: 0.1967364	total: 14.5s	remaining: 32.2s
# 311:	learn: 0.1966776	total: 14.6s	remaining: 32.2s
# 312:	learn: 0.1966420	total: 14.8s	remaining: 32.5s
# 313:	learn: 0.1965743	total: 15s	remaining: 32.8s
# 314:	learn: 0.1965307	total: 15.1s	remaining: 32.9s
# 315:	learn: 0.1964656	total: 15.2s	remaining: 32.9s
# 316:	learn: 0.1963948	total: 15.3s	remaining: 33s
# 317:	learn: 0.1963406	total: 15.4s	remaining: 33s
# 318:	learn: 0.1962783	total: 15.5s	remaining: 33.1s
# 319:	learn: 0.1962356	total: 15.5s	remaining: 33s
# 320:	learn: 0.1961098	total: 15.6s	remaining: 33s
# 321:	learn: 0.1960286	total: 15.9s	remaining: 33.5s
# 322:	learn: 0.1959877	total: 16s	remaining: 33.5s
# 323:	learn: 0.1958704	total: 16.1s	remaining: 33.5s
# 324:	learn: 0.1957906	total: 16.2s	remaining: 33.5s
# 325:	learn: 0.1957626	total: 16.2s	remaining: 33.5s
# 326:	learn: 0.1957570	total: 16.3s	remaining: 33.5s
# 327:	learn: 0.1956916	total: 16.6s	remaining: 34s
# 328:	learn: 0.1956256	total: 16.7s	remaining: 34s
# 329:	learn: 0.1955945	total: 16.8s	remaining: 34.1s
# 330:	learn: 0.1955081	total: 16.8s	remaining: 34s
# 331:	learn: 0.1954877	total: 17.1s	remaining: 34.5s
# 332:	learn: 0.1954346	total: 17.4s	remaining: 34.8s
# 333:	learn: 0.1954094	total: 17.4s	remaining: 34.7s
# 334:	learn: 0.1953708	total: 17.6s	remaining: 34.8s
# 335:	learn: 0.1953045	total: 17.7s	remaining: 35s
# 336:	learn: 0.1952588	total: 17.8s	remaining: 35s
# 337:	learn: 0.1951846	total: 17.8s	remaining: 34.9s
# 338:	learn: 0.1951435	total: 17.9s	remaining: 34.9s
# 339:	learn: 0.1950529	total: 18s	remaining: 34.9s
# 340:	learn: 0.1950012	total: 18s	remaining: 34.8s
# 341:	learn: 0.1949804	total: 18.1s	remaining: 34.8s
# 342:	learn: 0.1948668	total: 18.2s	remaining: 34.8s
# 343:	learn: 0.1947785	total: 18.2s	remaining: 34.7s
# 344:	learn: 0.1947225	total: 18.3s	remaining: 34.7s
# 345:	learn: 0.1946701	total: 18.5s	remaining: 35s
# 346:	learn: 0.1946264	total: 18.7s	remaining: 35.1s
# 347:	learn: 0.1945479	total: 18.7s	remaining: 35.1s
# 348:	learn: 0.1944701	total: 18.8s	remaining: 35.1s
# 349:	learn: 0.1944202	total: 18.8s	remaining: 35s
# 350:	learn: 0.1943209	total: 19s	remaining: 35.1s
# 351:	learn: 0.1942895	total: 19.1s	remaining: 35.2s
# 352:	learn: 0.1941999	total: 19.1s	remaining: 35.1s
# 353:	learn: 0.1941417	total: 19.2s	remaining: 35.1s
# 354:	learn: 0.1940837	total: 19.3s	remaining: 35.1s
# 355:	learn: 0.1939932	total: 19.3s	remaining: 35s
# 356:	learn: 0.1939327	total: 19.4s	remaining: 34.9s
# 357:	learn: 0.1938959	total: 19.4s	remaining: 34.9s
# 358:	learn: 0.1938578	total: 19.6s	remaining: 35s
# 359:	learn: 0.1937816	total: 19.8s	remaining: 35.2s
# 360:	learn: 0.1937245	total: 19.9s	remaining: 35.1s
# 361:	learn: 0.1936739	total: 19.9s	remaining: 35.1s
# 362:	learn: 0.1935802	total: 19.9s	remaining: 35s
# 363:	learn: 0.1935241	total: 20s	remaining: 34.9s
# 364:	learn: 0.1934622	total: 20.2s	remaining: 35.1s
# 365:	learn: 0.1934529	total: 20.2s	remaining: 35s
# 366:	learn: 0.1933763	total: 20.2s	remaining: 34.9s
# 367:	learn: 0.1933351	total: 20.5s	remaining: 35.2s
# 368:	learn: 0.1932829	total: 20.6s	remaining: 35.3s
# 369:	learn: 0.1932412	total: 20.7s	remaining: 35.2s
# 370:	learn: 0.1931896	total: 20.7s	remaining: 35.1s
# 371:	learn: 0.1931348	total: 20.7s	remaining: 35s
# 372:	learn: 0.1931147	total: 20.8s	remaining: 34.9s
# 373:	learn: 0.1930756	total: 20.8s	remaining: 34.8s
# 374:	learn: 0.1929896	total: 20.8s	remaining: 34.7s
# 375:	learn: 0.1929430	total: 20.9s	remaining: 34.6s
# 376:	learn: 0.1928909	total: 20.9s	remaining: 34.5s
# 377:	learn: 0.1928473	total: 20.9s	remaining: 34.4s
# 378:	learn: 0.1927845	total: 21s	remaining: 34.3s
# 379:	learn: 0.1927126	total: 21s	remaining: 34.3s
# 380:	learn: 0.1926598	total: 21.2s	remaining: 34.4s
# 381:	learn: 0.1926283	total: 21.2s	remaining: 34.4s
# 382:	learn: 0.1925774	total: 21.3s	remaining: 34.3s
# 383:	learn: 0.1925161	total: 21.3s	remaining: 34.2s
# 384:	learn: 0.1924739	total: 21.4s	remaining: 34.1s
# 385:	learn: 0.1924376	total: 21.4s	remaining: 34s
# 386:	learn: 0.1923751	total: 21.4s	remaining: 33.9s
# 387:	learn: 0.1923057	total: 21.5s	remaining: 33.9s
# 388:	learn: 0.1922433	total: 21.5s	remaining: 33.8s
# 389:	learn: 0.1921806	total: 21.5s	remaining: 33.7s
# 390:	learn: 0.1920913	total: 21.6s	remaining: 33.6s
# 391:	learn: 0.1920610	total: 21.6s	remaining: 33.5s
# 392:	learn: 0.1920361	total: 21.7s	remaining: 33.4s
# 393:	learn: 0.1920049	total: 21.7s	remaining: 33.4s
# 394:	learn: 0.1919367	total: 21.7s	remaining: 33.3s
# 395:	learn: 0.1918668	total: 21.8s	remaining: 33.2s
# 396:	learn: 0.1918328	total: 21.8s	remaining: 33.1s
# 397:	learn: 0.1917663	total: 21.9s	remaining: 33.1s
# 398:	learn: 0.1917082	total: 21.9s	remaining: 33.1s
# 399:	learn: 0.1916407	total: 22s	remaining: 33s
# 400:	learn: 0.1915938	total: 22s	remaining: 32.9s
# 401:	learn: 0.1915837	total: 22s	remaining: 32.8s
# 402:	learn: 0.1915803	total: 22.1s	remaining: 32.7s
# 403:	learn: 0.1915356	total: 22.1s	remaining: 32.6s
# 404:	learn: 0.1914953	total: 22.3s	remaining: 32.7s
# 405:	learn: 0.1914414	total: 22.3s	remaining: 32.6s
# 406:	learn: 0.1913397	total: 22.3s	remaining: 32.5s
# 407:	learn: 0.1913080	total: 22.5s	remaining: 32.6s
# 408:	learn: 0.1912533	total: 22.5s	remaining: 32.6s
# 409:	learn: 0.1911816	total: 22.6s	remaining: 32.5s
# 410:	learn: 0.1911167	total: 22.6s	remaining: 32.4s
# 411:	learn: 0.1910983	total: 22.7s	remaining: 32.3s
# 412:	learn: 0.1910606	total: 22.7s	remaining: 32.2s
# 413:	learn: 0.1909957	total: 22.7s	remaining: 32.1s
# 414:	learn: 0.1909396	total: 22.7s	remaining: 32.1s
# 415:	learn: 0.1909140	total: 22.8s	remaining: 32s
# 416:	learn: 0.1908756	total: 22.8s	remaining: 31.9s
# 417:	learn: 0.1908346	total: 22.8s	remaining: 31.8s
# 418:	learn: 0.1907980	total: 22.9s	remaining: 31.7s
# 419:	learn: 0.1907817	total: 22.9s	remaining: 31.6s
# 420:	learn: 0.1907457	total: 23.1s	remaining: 31.7s
# 421:	learn: 0.1907320	total: 23.1s	remaining: 31.7s
# 422:	learn: 0.1906931	total: 23.2s	remaining: 31.6s
# 423:	learn: 0.1906517	total: 23.2s	remaining: 31.5s
# 424:	learn: 0.1905544	total: 23.2s	remaining: 31.4s
# 425:	learn: 0.1905312	total: 23.2s	remaining: 31.3s
# 426:	learn: 0.1905206	total: 23.3s	remaining: 31.2s
# 427:	learn: 0.1904742	total: 23.4s	remaining: 31.3s
# 428:	learn: 0.1904596	total: 23.4s	remaining: 31.2s
# 429:	learn: 0.1903838	total: 23.5s	remaining: 31.1s
# 430:	learn: 0.1903123	total: 23.5s	remaining: 31s
# 431:	learn: 0.1902477	total: 23.5s	remaining: 30.9s
# 432:	learn: 0.1902257	total: 23.6s	remaining: 30.9s
# 433:	learn: 0.1901849	total: 23.6s	remaining: 30.8s
# 434:	learn: 0.1901479	total: 23.7s	remaining: 30.7s
# 435:	learn: 0.1900917	total: 23.7s	remaining: 30.7s
# 436:	learn: 0.1900141	total: 23.7s	remaining: 30.6s
# 437:	learn: 0.1899456	total: 23.8s	remaining: 30.5s
# 438:	learn: 0.1898870	total: 23.8s	remaining: 30.4s
# 439:	learn: 0.1898439	total: 23.8s	remaining: 30.3s
# 440:	learn: 0.1897888	total: 23.9s	remaining: 30.2s
# 441:	learn: 0.1897178	total: 24s	remaining: 30.3s
# 442:	learn: 0.1896166	total: 24.1s	remaining: 30.3s
# 443:	learn: 0.1895871	total: 24.1s	remaining: 30.2s
# 444:	learn: 0.1895715	total: 24.2s	remaining: 30.1s
# 445:	learn: 0.1895287	total: 24.4s	remaining: 30.3s
# 446:	learn: 0.1894972	total: 24.4s	remaining: 30.2s
# 447:	learn: 0.1894420	total: 24.4s	remaining: 30.1s
# 448:	learn: 0.1893827	total: 24.5s	remaining: 30s
# 449:	learn: 0.1892892	total: 24.5s	remaining: 29.9s
# 450:	learn: 0.1892287	total: 24.5s	remaining: 29.8s
# 451:	learn: 0.1891560	total: 24.5s	remaining: 29.7s
# 452:	learn: 0.1890965	total: 24.6s	remaining: 29.7s
# 453:	learn: 0.1890666	total: 24.7s	remaining: 29.7s
# 454:	learn: 0.1889740	total: 24.8s	remaining: 29.7s
# 455:	learn: 0.1889195	total: 24.9s	remaining: 29.7s
# 456:	learn: 0.1888616	total: 25.2s	remaining: 29.9s
# 457:	learn: 0.1888076	total: 25.2s	remaining: 29.9s
# 458:	learn: 0.1887682	total: 25.3s	remaining: 29.8s
# 459:	learn: 0.1887239	total: 25.3s	remaining: 29.7s
# 460:	learn: 0.1886881	total: 25.3s	remaining: 29.6s
# 461:	learn: 0.1886269	total: 25.4s	remaining: 29.6s
# 462:	learn: 0.1885793	total: 25.4s	remaining: 29.5s
# 463:	learn: 0.1885436	total: 25.6s	remaining: 29.5s
# 464:	learn: 0.1885230	total: 25.7s	remaining: 29.5s
# 465:	learn: 0.1884878	total: 25.8s	remaining: 29.5s
# 466:	learn: 0.1884598	total: 25.8s	remaining: 29.5s
# 467:	learn: 0.1884374	total: 25.9s	remaining: 29.4s
# 468:	learn: 0.1884129	total: 25.9s	remaining: 29.3s
# 469:	learn: 0.1883676	total: 26s	remaining: 29.3s
# 470:	learn: 0.1883111	total: 26.1s	remaining: 29.3s
# 471:	learn: 0.1882593	total: 26.2s	remaining: 29.3s
# 472:	learn: 0.1881779	total: 26.2s	remaining: 29.2s
# 473:	learn: 0.1881489	total: 26.4s	remaining: 29.3s
# 474:	learn: 0.1880705	total: 26.4s	remaining: 29.2s
# 475:	learn: 0.1880025	total: 26.4s	remaining: 29.1s
# 476:	learn: 0.1879553	total: 26.5s	remaining: 29s
# 477:	learn: 0.1879228	total: 26.5s	remaining: 28.9s
# 478:	learn: 0.1879042	total: 26.5s	remaining: 28.8s
# 479:	learn: 0.1879016	total: 26.6s	remaining: 28.9s
# 480:	learn: 0.1878660	total: 26.7s	remaining: 28.8s
# 481:	learn: 0.1878135	total: 26.7s	remaining: 28.7s
# 482:	learn: 0.1877841	total: 26.8s	remaining: 28.6s
# 483:	learn: 0.1877651	total: 26.8s	remaining: 28.6s
# 484:	learn: 0.1877625	total: 26.9s	remaining: 28.5s
# 485:	learn: 0.1877413	total: 26.9s	remaining: 28.5s
# 486:	learn: 0.1876988	total: 27s	remaining: 28.4s
# 487:	learn: 0.1876575	total: 27s	remaining: 28.4s
# 488:	learn: 0.1876081	total: 27.1s	remaining: 28.3s
# 489:	learn: 0.1876010	total: 27.2s	remaining: 28.3s
# 490:	learn: 0.1875658	total: 27.4s	remaining: 28.4s
# 491:	learn: 0.1874956	total: 27.4s	remaining: 28.3s
# 492:	learn: 0.1874679	total: 27.6s	remaining: 28.3s
# 493:	learn: 0.1874274	total: 27.7s	remaining: 28.4s
# 494:	learn: 0.1874041	total: 27.8s	remaining: 28.3s
# 495:	learn: 0.1873445	total: 27.8s	remaining: 28.3s
# 496:	learn: 0.1872946	total: 27.9s	remaining: 28.2s
# 497:	learn: 0.1872376	total: 28s	remaining: 28.2s
# 498:	learn: 0.1871766	total: 28s	remaining: 28.2s
# 499:	learn: 0.1871738	total: 28.1s	remaining: 28.1s
# 500:	learn: 0.1871536	total: 28.2s	remaining: 28s
# 501:	learn: 0.1870952	total: 28.3s	remaining: 28.1s
# 502:	learn: 0.1870402	total: 28.4s	remaining: 28.1s
# 503:	learn: 0.1869974	total: 28.4s	remaining: 28s
# 504:	learn: 0.1869746	total: 28.6s	remaining: 28s
# 505:	learn: 0.1869319	total: 28.6s	remaining: 27.9s
# 506:	learn: 0.1869056	total: 28.6s	remaining: 27.8s
# 507:	learn: 0.1868272	total: 28.7s	remaining: 27.8s
# 508:	learn: 0.1867534	total: 28.7s	remaining: 27.7s
# 509:	learn: 0.1866789	total: 28.7s	remaining: 27.6s
# 510:	learn: 0.1866438	total: 28.9s	remaining: 27.6s
# 511:	learn: 0.1866070	total: 29s	remaining: 27.6s
# 512:	learn: 0.1865633	total: 29s	remaining: 27.5s
# 513:	learn: 0.1865114	total: 29.1s	remaining: 27.5s
# 514:	learn: 0.1864623	total: 29.2s	remaining: 27.5s
# 515:	learn: 0.1864212	total: 29.2s	remaining: 27.4s
# 516:	learn: 0.1863703	total: 29.3s	remaining: 27.3s
# 517:	learn: 0.1863208	total: 29.3s	remaining: 27.3s
# 518:	learn: 0.1862887	total: 29.3s	remaining: 27.2s
# 519:	learn: 0.1862461	total: 29.4s	remaining: 27.1s
# 520:	learn: 0.1862009	total: 29.4s	remaining: 27s
# 521:	learn: 0.1861562	total: 29.4s	remaining: 27s
# 522:	learn: 0.1860986	total: 29.5s	remaining: 26.9s
# 523:	learn: 0.1860685	total: 29.5s	remaining: 26.8s
# 524:	learn: 0.1860572	total: 29.7s	remaining: 26.9s
# 525:	learn: 0.1859965	total: 29.8s	remaining: 26.9s
# 526:	learn: 0.1859443	total: 29.8s	remaining: 26.8s
# 527:	learn: 0.1859152	total: 29.9s	remaining: 26.7s
# 528:	learn: 0.1858725	total: 29.9s	remaining: 26.6s
# 529:	learn: 0.1857945	total: 29.9s	remaining: 26.5s
# 530:	learn: 0.1857460	total: 30s	remaining: 26.5s
# 531:	learn: 0.1856747	total: 30s	remaining: 26.4s
# 532:	learn: 0.1856500	total: 30.1s	remaining: 26.3s
# 533:	learn: 0.1856066	total: 30.1s	remaining: 26.3s
# 534:	learn: 0.1855464	total: 30.1s	remaining: 26.2s
# 535:	learn: 0.1854872	total: 30.1s	remaining: 26.1s
# 536:	learn: 0.1854632	total: 30.2s	remaining: 26s
# 537:	learn: 0.1854269	total: 30.2s	remaining: 25.9s
# 538:	learn: 0.1853876	total: 30.4s	remaining: 26s
# 539:	learn: 0.1853418	total: 30.4s	remaining: 25.9s
# 540:	learn: 0.1852885	total: 30.5s	remaining: 25.9s
# 541:	learn: 0.1852589	total: 30.6s	remaining: 25.9s
# 542:	learn: 0.1852311	total: 30.7s	remaining: 25.8s
# 543:	learn: 0.1851954	total: 30.8s	remaining: 25.8s
# 544:	learn: 0.1851897	total: 30.8s	remaining: 25.7s
# 545:	learn: 0.1851099	total: 30.8s	remaining: 25.6s
# 546:	learn: 0.1850780	total: 30.9s	remaining: 25.6s
# 547:	learn: 0.1850745	total: 30.9s	remaining: 25.5s
# 548:	learn: 0.1850523	total: 30.9s	remaining: 25.4s
# 549:	learn: 0.1850117	total: 31s	remaining: 25.3s
# 550:	learn: 0.1849477	total: 31.2s	remaining: 25.4s
# 551:	learn: 0.1849084	total: 31.2s	remaining: 25.3s
# 552:	learn: 0.1848602	total: 31.3s	remaining: 25.3s
# 553:	learn: 0.1848366	total: 31.3s	remaining: 25.2s
# 554:	learn: 0.1847933	total: 31.3s	remaining: 25.1s
# 555:	learn: 0.1847367	total: 31.3s	remaining: 25s
# 556:	learn: 0.1846504	total: 31.4s	remaining: 25s
# 557:	learn: 0.1846216	total: 31.4s	remaining: 24.9s
# 558:	learn: 0.1845594	total: 31.5s	remaining: 24.8s
# 559:	learn: 0.1845139	total: 31.5s	remaining: 24.7s
# 560:	learn: 0.1844718	total: 31.5s	remaining: 24.7s
# 561:	learn: 0.1844413	total: 31.6s	remaining: 24.6s
# 562:	learn: 0.1843745	total: 31.7s	remaining: 24.6s
# 563:	learn: 0.1843366	total: 31.8s	remaining: 24.6s
# 564:	learn: 0.1843035	total: 31.9s	remaining: 24.5s
# 565:	learn: 0.1842811	total: 31.9s	remaining: 24.5s
# 566:	learn: 0.1842366	total: 31.9s	remaining: 24.4s
# 567:	learn: 0.1841836	total: 32s	remaining: 24.3s
# 568:	learn: 0.1841523	total: 32s	remaining: 24.3s
# 569:	learn: 0.1840857	total: 32.1s	remaining: 24.2s
# 570:	learn: 0.1840460	total: 32.1s	remaining: 24.1s
# 571:	learn: 0.1840047	total: 32.1s	remaining: 24s
# 572:	learn: 0.1839769	total: 32.2s	remaining: 24s
# 573:	learn: 0.1839213	total: 32.2s	remaining: 23.9s
# 574:	learn: 0.1838722	total: 32.2s	remaining: 23.8s
# 575:	learn: 0.1838177	total: 32.3s	remaining: 23.8s
# 576:	learn: 0.1837970	total: 32.3s	remaining: 23.7s
# 577:	learn: 0.1837688	total: 32.4s	remaining: 23.6s
# 578:	learn: 0.1837222	total: 32.4s	remaining: 23.5s
# 579:	learn: 0.1836876	total: 32.4s	remaining: 23.5s
# 580:	learn: 0.1836577	total: 32.5s	remaining: 23.4s
# 581:	learn: 0.1836250	total: 32.5s	remaining: 23.4s
# 582:	learn: 0.1835888	total: 32.7s	remaining: 23.4s
# 583:	learn: 0.1835303	total: 32.8s	remaining: 23.3s
# 584:	learn: 0.1835057	total: 32.8s	remaining: 23.3s
# 585:	learn: 0.1834751	total: 32.8s	remaining: 23.2s
# 586:	learn: 0.1834495	total: 32.9s	remaining: 23.1s
# 587:	learn: 0.1833941	total: 33s	remaining: 23.1s
# 588:	learn: 0.1833525	total: 33.1s	remaining: 23.1s
# 589:	learn: 0.1833132	total: 33.1s	remaining: 23s
# 590:	learn: 0.1832655	total: 33.2s	remaining: 23s
# 591:	learn: 0.1832265	total: 33.2s	remaining: 22.9s
# 592:	learn: 0.1831662	total: 33.3s	remaining: 22.8s
# 593:	learn: 0.1830975	total: 33.3s	remaining: 22.8s
# 594:	learn: 0.1830522	total: 33.4s	remaining: 22.7s
# 595:	learn: 0.1830274	total: 33.4s	remaining: 22.6s
# 596:	learn: 0.1829981	total: 33.4s	remaining: 22.6s
# 597:	learn: 0.1829145	total: 33.5s	remaining: 22.5s
# 598:	learn: 0.1828907	total: 33.5s	remaining: 22.4s
# 599:	learn: 0.1828482	total: 33.6s	remaining: 22.4s
# 600:	learn: 0.1828142	total: 33.7s	remaining: 22.4s
# 601:	learn: 0.1827613	total: 33.7s	remaining: 22.3s
# 602:	learn: 0.1827308	total: 33.8s	remaining: 22.3s
# 603:	learn: 0.1826790	total: 33.9s	remaining: 22.2s
# 604:	learn: 0.1826532	total: 33.9s	remaining: 22.2s
# 605:	learn: 0.1825969	total: 34s	remaining: 22.1s
# 606:	learn: 0.1825776	total: 34s	remaining: 22s
# 607:	learn: 0.1825380	total: 34s	remaining: 21.9s
# 608:	learn: 0.1825042	total: 34.1s	remaining: 21.9s
# 609:	learn: 0.1824838	total: 34.1s	remaining: 21.8s
# 610:	learn: 0.1824342	total: 34.1s	remaining: 21.7s
# 611:	learn: 0.1824133	total: 34.2s	remaining: 21.7s
# 612:	learn: 0.1823676	total: 34.2s	remaining: 21.6s
# 613:	learn: 0.1823220	total: 34.3s	remaining: 21.6s
# 614:	learn: 0.1822765	total: 34.4s	remaining: 21.5s
# 615:	learn: 0.1822326	total: 34.4s	remaining: 21.5s
# 616:	learn: 0.1821997	total: 34.6s	remaining: 21.5s
# 617:	learn: 0.1821777	total: 34.7s	remaining: 21.4s
# 618:	learn: 0.1821159	total: 34.7s	remaining: 21.4s
# 619:	learn: 0.1820845	total: 34.7s	remaining: 21.3s
# 620:	learn: 0.1820317	total: 34.8s	remaining: 21.2s
# 621:	learn: 0.1820074	total: 34.8s	remaining: 21.2s
# 622:	learn: 0.1819777	total: 34.9s	remaining: 21.1s
# 623:	learn: 0.1819196	total: 34.9s	remaining: 21s
# 624:	learn: 0.1818872	total: 34.9s	remaining: 21s
# 625:	learn: 0.1818558	total: 35s	remaining: 20.9s
# 626:	learn: 0.1818051	total: 35s	remaining: 20.8s
# 627:	learn: 0.1817460	total: 35s	remaining: 20.7s
# 628:	learn: 0.1817146	total: 35s	remaining: 20.7s
# 629:	learn: 0.1816664	total: 35.1s	remaining: 20.6s
# 630:	learn: 0.1816374	total: 35.2s	remaining: 20.6s
# 631:	learn: 0.1816050	total: 35.3s	remaining: 20.6s
# 632:	learn: 0.1815441	total: 35.5s	remaining: 20.6s
# 633:	learn: 0.1814865	total: 35.5s	remaining: 20.5s
# 634:	learn: 0.1814387	total: 35.6s	remaining: 20.5s
# 635:	learn: 0.1814360	total: 35.6s	remaining: 20.4s
# 636:	learn: 0.1813757	total: 35.7s	remaining: 20.3s
# 637:	learn: 0.1813009	total: 35.7s	remaining: 20.3s
# 638:	learn: 0.1812678	total: 35.9s	remaining: 20.3s
# 639:	learn: 0.1812369	total: 35.9s	remaining: 20.2s
# 640:	learn: 0.1811904	total: 36s	remaining: 20.2s
# 641:	learn: 0.1811469	total: 36s	remaining: 20.1s
# 642:	learn: 0.1811229	total: 36.1s	remaining: 20s
# 643:	learn: 0.1810732	total: 36.1s	remaining: 20s
# 644:	learn: 0.1810250	total: 36.2s	remaining: 19.9s
# 645:	learn: 0.1809949	total: 36.2s	remaining: 19.8s
# 646:	learn: 0.1809584	total: 36.2s	remaining: 19.8s
# 647:	learn: 0.1809001	total: 36.2s	remaining: 19.7s
# 648:	learn: 0.1808617	total: 36.3s	remaining: 19.6s
# 649:	learn: 0.1808229	total: 36.4s	remaining: 19.6s
# 650:	learn: 0.1807979	total: 36.5s	remaining: 19.6s
# 651:	learn: 0.1807509	total: 36.5s	remaining: 19.5s
# 652:	learn: 0.1807440	total: 36.5s	remaining: 19.4s
# 653:	learn: 0.1806945	total: 36.6s	remaining: 19.4s
# 654:	learn: 0.1806558	total: 36.6s	remaining: 19.3s
# 655:	learn: 0.1806002	total: 36.7s	remaining: 19.2s
# 656:	learn: 0.1805456	total: 36.7s	remaining: 19.2s
# 657:	learn: 0.1805117	total: 36.7s	remaining: 19.1s
# 658:	learn: 0.1804773	total: 36.8s	remaining: 19s
# 659:	learn: 0.1804243	total: 36.9s	remaining: 19s
# 660:	learn: 0.1803674	total: 37s	remaining: 19s
# 661:	learn: 0.1803150	total: 37s	remaining: 18.9s
# 662:	learn: 0.1802797	total: 37.1s	remaining: 18.8s
# 663:	learn: 0.1802559	total: 37.1s	remaining: 18.8s
# 664:	learn: 0.1802301	total: 37.1s	remaining: 18.7s
# 665:	learn: 0.1802092	total: 37.2s	remaining: 18.6s
# 666:	learn: 0.1801672	total: 37.2s	remaining: 18.6s
# 667:	learn: 0.1801185	total: 37.2s	remaining: 18.5s
# 668:	learn: 0.1800731	total: 37.3s	remaining: 18.4s
# 669:	learn: 0.1800467	total: 37.3s	remaining: 18.4s
# 670:	learn: 0.1800021	total: 37.4s	remaining: 18.3s
# 671:	learn: 0.1799545	total: 37.4s	remaining: 18.3s
# 672:	learn: 0.1799028	total: 37.5s	remaining: 18.2s
# 673:	learn: 0.1798822	total: 37.5s	remaining: 18.1s
# 674:	learn: 0.1798769	total: 37.5s	remaining: 18.1s
# 675:	learn: 0.1798518	total: 37.6s	remaining: 18s
# 676:	learn: 0.1798015	total: 37.6s	remaining: 17.9s
# 677:	learn: 0.1797750	total: 37.7s	remaining: 17.9s
# 678:	learn: 0.1797219	total: 37.8s	remaining: 17.9s
# 679:	learn: 0.1796735	total: 37.9s	remaining: 17.8s
# 680:	learn: 0.1796391	total: 37.9s	remaining: 17.7s
# 681:	learn: 0.1796047	total: 37.9s	remaining: 17.7s
# 682:	learn: 0.1795987	total: 37.9s	remaining: 17.6s
# 683:	learn: 0.1795723	total: 38s	remaining: 17.5s
# 684:	learn: 0.1795547	total: 38s	remaining: 17.5s
# 685:	learn: 0.1794718	total: 38.1s	remaining: 17.4s
# 686:	learn: 0.1794375	total: 38.1s	remaining: 17.4s
# 687:	learn: 0.1793966	total: 38.1s	remaining: 17.3s
# 688:	learn: 0.1793684	total: 38.2s	remaining: 17.2s
# 689:	learn: 0.1793308	total: 38.2s	remaining: 17.2s
# 690:	learn: 0.1792817	total: 38.2s	remaining: 17.1s
# 691:	learn: 0.1792400	total: 38.3s	remaining: 17s
# 692:	learn: 0.1792032	total: 38.3s	remaining: 17s
# 693:	learn: 0.1791537	total: 38.3s	remaining: 16.9s
# 694:	learn: 0.1791423	total: 38.4s	remaining: 16.9s
# 695:	learn: 0.1790961	total: 38.5s	remaining: 16.8s
# 696:	learn: 0.1790550	total: 38.6s	remaining: 16.8s
# 697:	learn: 0.1790083	total: 38.7s	remaining: 16.7s
# 698:	learn: 0.1789715	total: 38.7s	remaining: 16.7s
# 699:	learn: 0.1789370	total: 38.7s	remaining: 16.6s
# 700:	learn: 0.1788899	total: 38.8s	remaining: 16.5s
# 701:	learn: 0.1788381	total: 38.8s	remaining: 16.5s
# 702:	learn: 0.1787827	total: 38.9s	remaining: 16.4s
# 703:	learn: 0.1787252	total: 39s	remaining: 16.4s
# 704:	learn: 0.1786758	total: 39.1s	remaining: 16.3s
# 705:	learn: 0.1785917	total: 39.1s	remaining: 16.3s
# 706:	learn: 0.1785423	total: 39.2s	remaining: 16.2s
# 707:	learn: 0.1785001	total: 39.2s	remaining: 16.2s
# 708:	learn: 0.1784452	total: 39.4s	remaining: 16.2s
# 709:	learn: 0.1784089	total: 39.4s	remaining: 16.1s
# 710:	learn: 0.1783412	total: 39.5s	remaining: 16.1s
# 711:	learn: 0.1782865	total: 39.6s	remaining: 16s
# 712:	learn: 0.1782808	total: 39.6s	remaining: 16s
# 713:	learn: 0.1782211	total: 39.7s	remaining: 15.9s
# 714:	learn: 0.1781790	total: 39.8s	remaining: 15.9s
# 715:	learn: 0.1781601	total: 39.9s	remaining: 15.8s
# 716:	learn: 0.1781177	total: 39.9s	remaining: 15.7s
# 717:	learn: 0.1780709	total: 39.9s	remaining: 15.7s
# 718:	learn: 0.1780480	total: 40s	remaining: 15.6s
# 719:	learn: 0.1779960	total: 40s	remaining: 15.6s
# 720:	learn: 0.1779496	total: 40s	remaining: 15.5s
# 721:	learn: 0.1779047	total: 40.1s	remaining: 15.4s
# 722:	learn: 0.1778526	total: 40.1s	remaining: 15.4s
# 723:	learn: 0.1778137	total: 40.1s	remaining: 15.3s
# 724:	learn: 0.1777448	total: 40.2s	remaining: 15.2s
# 725:	learn: 0.1776919	total: 40.2s	remaining: 15.2s
# 726:	learn: 0.1776493	total: 40.2s	remaining: 15.1s
# 727:	learn: 0.1776145	total: 40.3s	remaining: 15s
# 728:	learn: 0.1775954	total: 40.3s	remaining: 15s
# 729:	learn: 0.1775621	total: 40.3s	remaining: 14.9s
# 730:	learn: 0.1775169	total: 40.4s	remaining: 14.9s
# 731:	learn: 0.1774509	total: 40.4s	remaining: 14.8s
# 732:	learn: 0.1774079	total: 40.4s	remaining: 14.7s
# 733:	learn: 0.1773741	total: 40.5s	remaining: 14.7s
# 734:	learn: 0.1773320	total: 40.5s	remaining: 14.6s
# 735:	learn: 0.1772927	total: 40.7s	remaining: 14.6s
# 736:	learn: 0.1772388	total: 40.7s	remaining: 14.5s
# 737:	learn: 0.1772044	total: 40.7s	remaining: 14.5s
# 738:	learn: 0.1771630	total: 40.8s	remaining: 14.4s
# 739:	learn: 0.1771438	total: 40.8s	remaining: 14.3s
# 740:	learn: 0.1770915	total: 40.8s	remaining: 14.3s
# 741:	learn: 0.1770616	total: 40.9s	remaining: 14.2s
# 742:	learn: 0.1770181	total: 40.9s	remaining: 14.1s
# 743:	learn: 0.1769899	total: 40.9s	remaining: 14.1s
# 744:	learn: 0.1769706	total: 41s	remaining: 14s
# 745:	learn: 0.1769219	total: 41.1s	remaining: 14s
# 746:	learn: 0.1768845	total: 41.2s	remaining: 13.9s
# 747:	learn: 0.1768531	total: 41.2s	remaining: 13.9s
# 748:	learn: 0.1768281	total: 41.2s	remaining: 13.8s
# 749:	learn: 0.1767861	total: 41.3s	remaining: 13.8s
# 750:	learn: 0.1767526	total: 41.4s	remaining: 13.7s
# 751:	learn: 0.1767088	total: 41.5s	remaining: 13.7s
# 752:	learn: 0.1766786	total: 41.5s	remaining: 13.6s
# 753:	learn: 0.1766543	total: 41.5s	remaining: 13.5s
# 754:	learn: 0.1766119	total: 41.6s	remaining: 13.5s
# 755:	learn: 0.1765437	total: 41.6s	remaining: 13.4s
# 756:	learn: 0.1764875	total: 41.6s	remaining: 13.4s
# 757:	learn: 0.1764530	total: 41.7s	remaining: 13.3s
# 758:	learn: 0.1764262	total: 41.8s	remaining: 13.3s
# 759:	learn: 0.1763954	total: 41.9s	remaining: 13.2s
# 760:	learn: 0.1763515	total: 41.9s	remaining: 13.2s
# 761:	learn: 0.1763207	total: 41.9s	remaining: 13.1s
# 762:	learn: 0.1762685	total: 42s	remaining: 13s
# 763:	learn: 0.1762654	total: 42s	remaining: 13s
# 764:	learn: 0.1762183	total: 42s	remaining: 12.9s
# 765:	learn: 0.1761943	total: 42.1s	remaining: 12.8s
# 766:	learn: 0.1761481	total: 42.1s	remaining: 12.8s
# 767:	learn: 0.1761287	total: 42.1s	remaining: 12.7s
# 768:	learn: 0.1760999	total: 42.2s	remaining: 12.7s
# 769:	learn: 0.1760586	total: 42.2s	remaining: 12.6s
# 770:	learn: 0.1760050	total: 42.2s	remaining: 12.5s
# 771:	learn: 0.1759464	total: 42.3s	remaining: 12.5s
# 772:	learn: 0.1759194	total: 42.3s	remaining: 12.4s
# 773:	learn: 0.1758790	total: 42.3s	remaining: 12.4s
# 774:	learn: 0.1758340	total: 42.3s	remaining: 12.3s
# 775:	learn: 0.1758064	total: 42.4s	remaining: 12.2s
# 776:	learn: 0.1757900	total: 42.4s	remaining: 12.2s
# 777:	learn: 0.1757337	total: 42.4s	remaining: 12.1s
# 778:	learn: 0.1756869	total: 42.6s	remaining: 12.1s
# 779:	learn: 0.1756271	total: 42.6s	remaining: 12s
# 780:	learn: 0.1756056	total: 42.6s	remaining: 12s
# 781:	learn: 0.1755536	total: 42.7s	remaining: 11.9s
# 782:	learn: 0.1754914	total: 42.8s	remaining: 11.9s
# 783:	learn: 0.1754640	total: 42.9s	remaining: 11.8s
# 784:	learn: 0.1754152	total: 42.9s	remaining: 11.8s
# 785:	learn: 0.1753676	total: 43s	remaining: 11.7s
# 786:	learn: 0.1753129	total: 43s	remaining: 11.6s
# 787:	learn: 0.1752945	total: 43s	remaining: 11.6s
# 788:	learn: 0.1752567	total: 43.1s	remaining: 11.5s
# 789:	learn: 0.1752260	total: 43.1s	remaining: 11.5s
# 790:	learn: 0.1752086	total: 43.1s	remaining: 11.4s
# 791:	learn: 0.1751821	total: 43.2s	remaining: 11.3s
# 792:	learn: 0.1751231	total: 43.4s	remaining: 11.3s
# 793:	learn: 0.1750784	total: 43.4s	remaining: 11.3s
# 794:	learn: 0.1750325	total: 43.5s	remaining: 11.2s
# 795:	learn: 0.1750053	total: 43.5s	remaining: 11.2s
# 796:	learn: 0.1749688	total: 43.6s	remaining: 11.1s
# 797:	learn: 0.1749340	total: 43.7s	remaining: 11.1s
# 798:	learn: 0.1748981	total: 43.8s	remaining: 11s
# 799:	learn: 0.1748649	total: 43.9s	remaining: 11s
# 800:	learn: 0.1748466	total: 43.9s	remaining: 10.9s
# 801:	learn: 0.1747994	total: 44s	remaining: 10.9s
# 802:	learn: 0.1747632	total: 44s	remaining: 10.8s
# 803:	learn: 0.1747260	total: 44s	remaining: 10.7s
# 804:	learn: 0.1747196	total: 44.1s	remaining: 10.7s
# 805:	learn: 0.1746892	total: 44.1s	remaining: 10.6s
# 806:	learn: 0.1746613	total: 44.2s	remaining: 10.6s
# 807:	learn: 0.1746411	total: 44.2s	remaining: 10.5s
# 808:	learn: 0.1746117	total: 44.3s	remaining: 10.5s
# 809:	learn: 0.1745738	total: 44.4s	remaining: 10.4s
# 810:	learn: 0.1745537	total: 44.4s	remaining: 10.4s
# 811:	learn: 0.1745353	total: 44.5s	remaining: 10.3s
# 812:	learn: 0.1744944	total: 44.5s	remaining: 10.2s
# 813:	learn: 0.1744534	total: 44.5s	remaining: 10.2s
# 814:	learn: 0.1744185	total: 44.5s	remaining: 10.1s
# 815:	learn: 0.1743828	total: 44.6s	remaining: 10.1s
# 816:	learn: 0.1743272	total: 44.6s	remaining: 9.99s
# 817:	learn: 0.1742932	total: 44.6s	remaining: 9.93s
# 818:	learn: 0.1742684	total: 44.7s	remaining: 9.88s
# 819:	learn: 0.1742390	total: 44.7s	remaining: 9.82s
# 820:	learn: 0.1742014	total: 44.8s	remaining: 9.76s
# 821:	learn: 0.1741781	total: 44.9s	remaining: 9.73s
# 822:	learn: 0.1741441	total: 45s	remaining: 9.67s
# 823:	learn: 0.1741163	total: 45s	remaining: 9.61s
# 824:	learn: 0.1740994	total: 45s	remaining: 9.55s
# 825:	learn: 0.1740716	total: 45.1s	remaining: 9.49s
# 826:	learn: 0.1740231	total: 45.1s	remaining: 9.43s
# 827:	learn: 0.1739772	total: 45.1s	remaining: 9.37s
# 828:	learn: 0.1739267	total: 45.2s	remaining: 9.32s
# 829:	learn: 0.1738856	total: 45.2s	remaining: 9.26s
# 830:	learn: 0.1738434	total: 45.2s	remaining: 9.2s
# 831:	learn: 0.1738349	total: 45.3s	remaining: 9.14s
# 832:	learn: 0.1738061	total: 45.3s	remaining: 9.08s
# 833:	learn: 0.1737848	total: 45.3s	remaining: 9.02s
# 834:	learn: 0.1737597	total: 45.4s	remaining: 8.96s
# 835:	learn: 0.1737265	total: 45.5s	remaining: 8.92s
# 836:	learn: 0.1737079	total: 45.5s	remaining: 8.87s
# 837:	learn: 0.1736804	total: 45.6s	remaining: 8.82s
# 838:	learn: 0.1736572	total: 45.7s	remaining: 8.76s
# 839:	learn: 0.1736324	total: 45.7s	remaining: 8.7s
# 840:	learn: 0.1736172	total: 45.7s	remaining: 8.65s
# 841:	learn: 0.1735913	total: 45.9s	remaining: 8.61s
# 842:	learn: 0.1735743	total: 45.9s	remaining: 8.55s
# 843:	learn: 0.1735322	total: 46s	remaining: 8.49s
# 844:	learn: 0.1735101	total: 46s	remaining: 8.44s
# 845:	learn: 0.1734658	total: 46.1s	remaining: 8.38s
# 846:	learn: 0.1734420	total: 46.1s	remaining: 8.33s
# 847:	learn: 0.1734132	total: 46.1s	remaining: 8.27s
# 848:	learn: 0.1733729	total: 46.2s	remaining: 8.21s
# 849:	learn: 0.1733585	total: 46.2s	remaining: 8.16s
# 850:	learn: 0.1733210	total: 46.3s	remaining: 8.1s
# 851:	learn: 0.1732997	total: 46.3s	remaining: 8.04s
# 852:	learn: 0.1732746	total: 46.3s	remaining: 7.98s
# 853:	learn: 0.1732181	total: 46.4s	remaining: 7.93s
# 854:	learn: 0.1731964	total: 46.5s	remaining: 7.88s
# 855:	learn: 0.1731485	total: 46.6s	remaining: 7.83s
# 856:	learn: 0.1731179	total: 46.6s	remaining: 7.77s
# 857:	learn: 0.1730941	total: 46.6s	remaining: 7.71s
# 858:	learn: 0.1730440	total: 46.7s	remaining: 7.66s
# 859:	learn: 0.1729823	total: 46.7s	remaining: 7.6s
# 860:	learn: 0.1729340	total: 46.7s	remaining: 7.54s
# 861:	learn: 0.1728865	total: 46.8s	remaining: 7.49s
# 862:	learn: 0.1728489	total: 46.8s	remaining: 7.43s
# 863:	learn: 0.1728348	total: 46.8s	remaining: 7.37s
# 864:	learn: 0.1727910	total: 46.9s	remaining: 7.31s
# 865:	learn: 0.1727668	total: 46.9s	remaining: 7.26s
# 866:	learn: 0.1727193	total: 46.9s	remaining: 7.2s
# 867:	learn: 0.1726923	total: 47s	remaining: 7.14s
# 868:	learn: 0.1726621	total: 47s	remaining: 7.08s
# 869:	learn: 0.1726457	total: 47s	remaining: 7.03s
# 870:	learn: 0.1726040	total: 47.1s	remaining: 6.97s
# 871:	learn: 0.1725440	total: 47.1s	remaining: 6.91s
# 872:	learn: 0.1725122	total: 47.1s	remaining: 6.86s
# 873:	learn: 0.1724773	total: 47.2s	remaining: 6.8s
# 874:	learn: 0.1724309	total: 47.2s	remaining: 6.74s
# 875:	learn: 0.1723817	total: 47.3s	remaining: 6.7s
# 876:	learn: 0.1723388	total: 47.4s	remaining: 6.64s
# 877:	learn: 0.1723085	total: 47.4s	remaining: 6.59s
# 878:	learn: 0.1722849	total: 47.4s	remaining: 6.53s
# 879:	learn: 0.1722527	total: 47.5s	remaining: 6.47s
# 880:	learn: 0.1722253	total: 47.5s	remaining: 6.42s
# 881:	learn: 0.1722026	total: 47.5s	remaining: 6.36s
# 882:	learn: 0.1721673	total: 47.6s	remaining: 6.3s
# 883:	learn: 0.1721391	total: 47.6s	remaining: 6.25s
# 884:	learn: 0.1721217	total: 47.6s	remaining: 6.19s
# 885:	learn: 0.1721001	total: 47.7s	remaining: 6.14s
# 886:	learn: 0.1720785	total: 47.7s	remaining: 6.08s
# 887:	learn: 0.1720444	total: 47.8s	remaining: 6.03s
# 888:	learn: 0.1720286	total: 47.8s	remaining: 5.97s
# 889:	learn: 0.1720265	total: 48s	remaining: 5.93s
# 890:	learn: 0.1719911	total: 48s	remaining: 5.88s
# 891:	learn: 0.1719696	total: 48.1s	remaining: 5.82s
# 892:	learn: 0.1719498	total: 48.1s	remaining: 5.76s
# 893:	learn: 0.1719192	total: 48.2s	remaining: 5.71s
# 894:	learn: 0.1718832	total: 48.2s	remaining: 5.66s
# 895:	learn: 0.1718500	total: 48.3s	remaining: 5.6s
# 896:	learn: 0.1718191	total: 48.3s	remaining: 5.55s
# 897:	learn: 0.1717828	total: 48.4s	remaining: 5.49s
# 898:	learn: 0.1717689	total: 48.4s	remaining: 5.44s
# 899:	learn: 0.1717518	total: 48.5s	remaining: 5.38s
# 900:	learn: 0.1717094	total: 48.5s	remaining: 5.33s
# 901:	learn: 0.1716819	total: 48.5s	remaining: 5.27s
# 902:	learn: 0.1716220	total: 48.6s	remaining: 5.22s
# 903:	learn: 0.1715814	total: 48.7s	remaining: 5.17s
# 904:	learn: 0.1715312	total: 48.9s	remaining: 5.13s
# 905:	learn: 0.1715100	total: 48.9s	remaining: 5.08s
# 906:	learn: 0.1714580	total: 49s	remaining: 5.02s
# 907:	learn: 0.1714287	total: 49s	remaining: 4.97s
# 908:	learn: 0.1713768	total: 49.1s	remaining: 4.91s
# 909:	learn: 0.1713236	total: 49.1s	remaining: 4.86s
# 910:	learn: 0.1712921	total: 49.2s	remaining: 4.8s
# 911:	learn: 0.1712762	total: 49.2s	remaining: 4.75s
# 912:	learn: 0.1712403	total: 49.4s	remaining: 4.71s
# 913:	learn: 0.1711899	total: 49.4s	remaining: 4.65s
# 914:	learn: 0.1711592	total: 49.5s	remaining: 4.6s
# 915:	learn: 0.1711260	total: 49.6s	remaining: 4.54s
# 916:	learn: 0.1710967	total: 49.6s	remaining: 4.49s
# 917:	learn: 0.1710575	total: 49.7s	remaining: 4.43s
# 918:	learn: 0.1710457	total: 49.7s	remaining: 4.38s
# 919:	learn: 0.1710279	total: 49.7s	remaining: 4.32s
# 920:	learn: 0.1710074	total: 49.8s	remaining: 4.27s
# 921:	learn: 0.1709832	total: 49.9s	remaining: 4.22s
# 922:	learn: 0.1709311	total: 50s	remaining: 4.17s
# 923:	learn: 0.1708838	total: 50s	remaining: 4.11s
# 924:	learn: 0.1708755	total: 50.1s	remaining: 4.06s
# 925:	learn: 0.1708409	total: 50.1s	remaining: 4s
# 926:	learn: 0.1708234	total: 50.1s	remaining: 3.95s
# 927:	learn: 0.1707744	total: 50.2s	remaining: 3.89s
# 928:	learn: 0.1707557	total: 50.2s	remaining: 3.84s
# 929:	learn: 0.1707162	total: 50.2s	remaining: 3.78s
# 930:	learn: 0.1706973	total: 50.3s	remaining: 3.73s
# 931:	learn: 0.1706518	total: 50.5s	remaining: 3.68s
# 932:	learn: 0.1706232	total: 50.5s	remaining: 3.63s
# 933:	learn: 0.1705861	total: 50.5s	remaining: 3.57s
# 934:	learn: 0.1705405	total: 50.6s	remaining: 3.52s
# 935:	learn: 0.1705200	total: 50.6s	remaining: 3.46s
# 936:	learn: 0.1704508	total: 50.6s	remaining: 3.4s
# 937:	learn: 0.1704030	total: 50.7s	remaining: 3.35s
# 938:	learn: 0.1703813	total: 50.7s	remaining: 3.29s
# 939:	learn: 0.1703628	total: 50.8s	remaining: 3.24s
# 940:	learn: 0.1703313	total: 50.9s	remaining: 3.19s
# 941:	learn: 0.1703127	total: 51s	remaining: 3.14s
# 942:	learn: 0.1702736	total: 51.1s	remaining: 3.09s
# 943:	learn: 0.1702346	total: 51.1s	remaining: 3.03s
# 944:	learn: 0.1701896	total: 51.2s	remaining: 2.98s
# 945:	learn: 0.1701610	total: 51.2s	remaining: 2.92s
# 946:	learn: 0.1701117	total: 51.3s	remaining: 2.87s
# 947:	learn: 0.1700862	total: 51.4s	remaining: 2.82s
# 948:	learn: 0.1700416	total: 51.4s	remaining: 2.76s
# 949:	learn: 0.1700182	total: 51.5s	remaining: 2.71s
# 950:	learn: 0.1699965	total: 51.5s	remaining: 2.65s
# 951:	learn: 0.1699772	total: 51.5s	remaining: 2.6s
# 952:	learn: 0.1699676	total: 51.6s	remaining: 2.54s
# 953:	learn: 0.1699042	total: 51.6s	remaining: 2.49s
# 954:	learn: 0.1698643	total: 51.6s	remaining: 2.43s
# 955:	learn: 0.1698230	total: 51.7s	remaining: 2.38s
# 956:	learn: 0.1697946	total: 51.8s	remaining: 2.33s
# 957:	learn: 0.1697875	total: 51.9s	remaining: 2.27s
# 958:	learn: 0.1697439	total: 51.9s	remaining: 2.22s
# 959:	learn: 0.1696928	total: 52s	remaining: 2.17s
# 960:	learn: 0.1696581	total: 52.1s	remaining: 2.11s
# 961:	learn: 0.1696333	total: 52.2s	remaining: 2.06s
# 962:	learn: 0.1695986	total: 52.2s	remaining: 2s
# 963:	learn: 0.1695630	total: 52.3s	remaining: 1.95s
# 964:	learn: 0.1695068	total: 52.4s	remaining: 1.9s
# 965:	learn: 0.1694704	total: 52.4s	remaining: 1.84s
# 966:	learn: 0.1694265	total: 52.5s	remaining: 1.79s
# 967:	learn: 0.1694005	total: 52.6s	remaining: 1.74s
# 968:	learn: 0.1693520	total: 52.7s	remaining: 1.69s
# 969:	learn: 0.1693096	total: 52.7s	remaining: 1.63s
# 970:	learn: 0.1692767	total: 52.8s	remaining: 1.58s
# 971:	learn: 0.1692379	total: 52.9s	remaining: 1.52s
# 972:	learn: 0.1692154	total: 53s	remaining: 1.47s
# 973:	learn: 0.1691864	total: 53s	remaining: 1.41s
# 974:	learn: 0.1691699	total: 53s	remaining: 1.36s
# 975:	learn: 0.1691511	total: 53.1s	remaining: 1.31s
# 976:	learn: 0.1691199	total: 53.2s	remaining: 1.25s
# 977:	learn: 0.1690729	total: 53.2s	remaining: 1.2s
# 978:	learn: 0.1690243	total: 53.3s	remaining: 1.14s
# 979:	learn: 0.1690055	total: 53.4s	remaining: 1.09s
# 980:	learn: 0.1689851	total: 53.5s	remaining: 1.04s
# 981:	learn: 0.1689503	total: 53.6s	remaining: 982ms
# 982:	learn: 0.1689423	total: 53.6s	remaining: 927ms
# 983:	learn: 0.1689228	total: 53.7s	remaining: 872ms
# 984:	learn: 0.1688884	total: 53.8s	remaining: 820ms
# 985:	learn: 0.1688697	total: 53.9s	remaining: 765ms
# 986:	learn: 0.1688439	total: 53.9s	remaining: 710ms
# 987:	learn: 0.1688209	total: 53.9s	remaining: 655ms
# 988:	learn: 0.1687903	total: 54s	remaining: 600ms
# 989:	learn: 0.1687558	total: 54.1s	remaining: 546ms
# 990:	learn: 0.1687109	total: 54.2s	remaining: 492ms
# 991:	learn: 0.1686807	total: 54.2s	remaining: 437ms
# 992:	learn: 0.1686558	total: 54.2s	remaining: 382ms
# 993:	learn: 0.1686335	total: 54.3s	remaining: 328ms
# 994:	learn: 0.1685971	total: 54.4s	remaining: 274ms
# 995:	learn: 0.1685684	total: 54.5s	remaining: 219ms
# 996:	learn: 0.1685471	total: 54.5s	remaining: 164ms
# 997:	learn: 0.1685284	total: 54.5s	remaining: 109ms
# 998:	learn: 0.1685118	total: 54.6s	remaining: 54.6ms
# 999:	learn: 0.1684910	total: 54.7s	remaining: 0us
#
# KS Test Results: {'loan_amount': 0.5966906872515435, 'number_of_defaults': 0.6046245156692129, 'outstanding_balance': 0.5164578947819605, 'interest_rate': 0.9663201625214487, 'age': 0.4340766408712714, 'remaining term': 0.21053342449692447, 'salary': 0.39355705681045416}
# PSI Results (Numeric Features): {'loan_amount': 0.0, 'number_of_defaults': 0.00016505378574296052, 'outstanding_balance': 23.025697304268473, 'interest_rate': 0.27820638834347183, 'age': 0.0, 'remaining term': 23.025697304268473, 'salary': 0.0}
# PSI Results (Categorical Features): {'job': 0.0008151374518336347, 'location': 0.001285775742180727, 'marital_status': 4.4968908122849855e-05, 'gender': 0.0008035400434662413}
# ROC AUC: 0.92

# %% [markdown]
# ### PIPELINE REVIEW
# - It retains our High ROC AUC SCORE of 0.92 (92%)
# - It intergrates seamlessly our custom classes, models and preprocessing.

# %% [markdown]
# ### Saving the Model
#
# To save the trained model for future use, we use the `joblib` library. This allows us to serialize the model object and store it in a file. Here’s how you can do it:

# %%
import joblib

joblib.dump(model, 'model_file.pkl')
# Out:
# ['model_file.pkl']

# %% [markdown]
# ### **3. Next Steps**
#
# Outline potential next steps or actions that could be taken based on the current state of the project.
#
# ```markdown
# ## Next Steps
#
# 1. **Model Deployment:** Deploy the saved model to a production environment or API endpoint.
# 2. **Further Evaluation:** Conduct additional testing with new data or on different subsets of data.
# 3. **Model Monitoring:** Implement monitoring to track the model's performance over time.
# 4. **Documentation:** Prepare detailed documentation for the model and its deployment process.
# 5. **Feature Enhancements:** Explore further feature engineering to potentially improve model performance
